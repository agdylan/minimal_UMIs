# %% [markdown]
# # Bam file Processing

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
import sklearn
import anndata as ad 
from tqdm import tqdm as tqdm
import pysam

import scanpy as sc

# %% [markdown]
# ## 1. Load and Process Bam file Output from cellranger

# %% [markdown]
# ### Create and save a list of the barcodes (cells) of the 1k and 10k PBMCs

# %%
# import gzip

# # Define the input and output file names for 10k
# # input_file = '/data/dagyeman/cellranger/10k_PBMCs/new_results/outs/filtered_feature_bc_matrix/barcodes.tsv.gz'  # Update with the correct path if needed
# # output_file = '/data/dagyeman/cellranger/10k_PBMCs/new_results/outs/barcodes.txt'      # The output file name

# # Defind the input and output files for 1k
# input_file = '/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/results/outs/filtered_feature_bc_matrix/barcodes.tsv.gz'  # Update with the correct path if needed
# output_file = '/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/results/outs/barcodes.txt'      # The output file name

# # Open the gzipped TSV file and the output text file
# with gzip.open(input_file, 'rt') as f_in, open(output_file, 'w') as f_out:
#     for line in f_in:
#         f_out.write(line)

# print(f"Converted {input_file} to {output_file}")
# Out:
# Converted /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/results/outs/filtered_feature_bc_matrix/barcodes.tsv.gz to /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/results/outs/barcodes.txt

# %% [markdown]
# #### Load the Barcodes list from datasets saved above

# %%
import numpy as np

# Specify the path to the .txt file for 10K PBMCs
# load_path = "/data/dagyeman/cellranger/10k_PBMCs/new_results/outs/barcodes.txt"  # Adjust this to the correct path

load_path = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/results/outs/barcodes.txt"  # Adjust this to the correct path


# Load the barcodes from the .txt file
barcodes_loaded = np.loadtxt(load_path, dtype=str)

# Verify the barcodes are loaded
print(barcodes_loaded)
# Out:
# ['AAACCCAAGGAGAGTA-1' 'AAACGCTTCAGCCCAG-1' 'AAAGAACAGACGACTG-1' ...
#  'TTTGGTTAGTAACCTC-1' 'TTTGGTTGTAGAATAC-1' 'TTTGTTGCAATTAGGA-1']

# %% [markdown]
# #### Filters a BAM file to keep only reads whose cell barcodes match a given list, saving the result to a new BAM file.

# %%
import pysam
from tqdm import tqdm

# Path to the input BAM file for 1k
annotated_bam_path = '/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/results/outs/possorted_genome_bam.bam'

# Path to the input BAM file for 10k
# annotated_bam_path = '/data/dagyeman/cellranger/10k_PBMCs/new_results/outs/possorted_genome_bam.bam'

# Path to the output filtered BAM file for 1k
filtered_bam_path = '/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/filtered_1k_PBMCS_bam.bam'

# Path to the output filtered BAM file for 10k
# filtered_bam_path = '/data/dagyeman/cellranger/bam_file_analysis/filtered_10k_PBMCS_bam.bam'

# Load the list of barcodes of interest (bc_list)
bc_list = set(barcodes_loaded)  # Using a set for faster lookup

# Open the input BAM file for reading
with pysam.AlignmentFile(annotated_bam_path, "rb") as bam_file:
    # Open the output BAM file for writing, copying the header from the input BAM
    with pysam.AlignmentFile(filtered_bam_path, "wb", header=bam_file.header) as filtered_bam_file:
        # Iterate over each read in the BAM file
        for read in tqdm(bam_file):
            # Check if the read has both 'CB' (cell barcode) and 'GN' (gene name) tags
            if read.has_tag('CB') and read.has_tag('GN'):
                CB = read.get_tag('CB')
                # If the barcode is in the list of barcodes of interest, write the read to the new BAM file
                if CB in bc_list:
                    filtered_bam_file.write(read)

print(f"Filtered BAM file saved to {filtered_bam_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      11 filtered_bam_path = '/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/filtered_1k_PBMCS_bam.bam'
#      13 # Path to the output filtered BAM file for 10k
#      14 # filtered_bam_path = '/data/dagyeman/cellranger/bam_file_analysis/filtered_10k_PBMCS_bam.bam'
#      15
#      16 # Load the list of barcodes of interest (bc_list)
# ---> 17 bc_list = set(barcodes_loaded)  # Using a set for faster lookup
#      19 # Open the input BAM file for reading
#      20 with pysam.AlignmentFile(annotated_bam_path, "rb") as bam_file:
#      21     # Open the output BAM file for writing, copying the header from the input BAM
#
# NameError: name 'barcodes_loaded' is not defined

# %% [markdown]
# #### Extracts cell barcodes, genes, and UMIs from a filtered BAM file and saves them into a pandas DataFrame.

# %%
import pysam
import pandas as pd

# Path to the filtered BAM file
filtered_bam_path = '/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/filtered_1k_PBMCS_bam.bam' # filtered path for 1k dataset 
# filtered_bam_path = '/data/dagyeman/cellranger/bam_file_analysis/filtered_10k_PBMCS_bam.bam' # filtered bam path for 10k dataset

# List to store rows of data (barcode, gene, UMI)
data = []

# Open the filtered BAM file for reading
with pysam.AlignmentFile(filtered_bam_path, "rb") as bam_file:
    # Iterate over each read in the BAM file
    for read in bam_file:
        # Check if the read has 'CB' (cell barcode), 'GN' (gene name), and 'UB' (UMI) tags
        if read.has_tag('CB') and read.has_tag('GN') and read.has_tag('UR'):
            # Extract the 'CB' (cell barcode), 'GN' (gene name), and 'UB' (UMI) tags
            barcode = read.get_tag('CB')
            gene = read.get_tag('GN')
            umi = read.get_tag('UR')
            
            # Append the row to the data list
            data.append([barcode, gene, umi])

# Convert the list into a pandas DataFrame
df = pd.DataFrame(data, columns=['barcode', 'gene', 'UMI'])

# Show the first few rows of the DataFrame
print(df.head())
# Out:
#               barcode        gene           UMI
# 0  GCTGCAGGTTGACGGA-1  AL627309.1  ATGAATTCGTTT
# 1  GCTGCAGGTTGACGGA-1  AL627309.1  ATGAATTCGTTT
# 2  CTGCCTATCTTGATTC-1  AL627309.1  CGGGTACTGCGC
# 3  GCGAGAAAGTTGTAGA-1  AL627309.1  TTGTAAAATACG
# 4  GGTCTGGTCAGACATC-1  AL627309.1  GGAAATCTGCGT

# %% [markdown]
# #### Generating dataframe containing information for all reads in the filtered bam file

# %%
# import pandas as pd


# # Loop through shortened UMI lengths from 1 to 12
# for k in range(1, 13):
#     # Shorten the 'UMI' to the first 'k' bases
#     df[f'UMI_{k}'] = df.UMI.str[:k]
    
#     # Group by 'barcode' and 'gene' and count the number of unique shortened UMIs for each combination
#     grouped_df = df.groupby(['barcode', 'gene'])[f'UMI_{k}'].nunique().reset_index()
    
#     # Rename the column to reflect that it's counting unique UMIs of length 'k'
#     grouped_df.rename(columns={f'UMI_{k}': f'unique_UMI_count_{k}'}, inplace=True)
    
#     # Optionally, you can store the resulting DataFrame for each 'k' or print the first few rows
#     print(f"Unique UMI counts for UMI length {k}:")
#     print(grouped_df.head())

# # Example: To merge results across different lengths (optional)
# # Merging results for all k values across lengths 1-12 into one DataFrame (if needed)
# final_df = df.groupby(['barcode', 'gene']).agg({f'UMI_{k}': 'nunique' for k in range(1, 13)}).reset_index()

# # Rename the columns accordingly to reflect the unique UMI counts for each length
# final_df.columns = ['barcode', 'gene'] + [f'unique_UMI_count_{k}' for k in range(1, 13)]

# # Show the first few rows of the final merged DataFrame
# print(final_df.head())

# %% [markdown]
# ## Exploring the Uniformity of UMI

# %%
import pandas as pd

# Filter out UMIs that contain 'N'
df = df[~df['UMI'].str.contains('N')]

# %%
# Loop through shortened UMI lengths from 1 to 12
for k in range(1, 13):
    # Shorten the 'UMI' to the first 'k' bases
    df[f'UMI_{k}'] = df.UMI.str[:k]
    
    # Group by 'barcode' and 'gene' and count the number of unique shortened UMIs for each combination
    grouped_df = df.groupby(['barcode', 'gene'])[f'UMI_{k}'].nunique().reset_index()
    
    # Rename the column to reflect that it's counting unique UMIs of length 'k'
    grouped_df.rename(columns={f'UMI_{k}': f'unique_UMI_count_{k}'}, inplace=True)
    
    # Optionally, you can store the resulting DataFrame for each 'k' or print the first few rows
    print(f"Unique UMI counts for UMI length {k}:")
    print(grouped_df.head())

# Example: To merge results across different lengths (optional)
# Merging results for all k values across lengths 1-12 into one DataFrame (if needed)
final_df = df.groupby(['barcode', 'gene']).agg({f'UMI_{k}': 'nunique' for k in range(1, 13)}).reset_index()

# Rename the columns accordingly to reflect the unique UMI counts for each length
final_df.columns = ['barcode', 'gene'] + [f'unique_UMI_count_{k}' for k in range(1, 13)]

# Show the first few rows of the final merged DataFrame
print(final_df.head())
# Out:
# Unique UMI counts for UMI length 1:
#               barcode   gene  unique_UMI_count_1
# 0  AAACCCAAGGAGAGTA-1   AAK1                   3
# 1  AAACCCAAGGAGAGTA-1   AAMP                   2
# 2  AAACCCAAGGAGAGTA-1   AATK                   1
# 3  AAACCCAAGGAGAGTA-1   ABAT                   2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                   2
# Unique UMI counts for UMI length 2:
#               barcode   gene  unique_UMI_count_2
# 0  AAACCCAAGGAGAGTA-1   AAK1                   4
# 1  AAACCCAAGGAGAGTA-1   AAMP                   2
# 2  AAACCCAAGGAGAGTA-1   AATK                   1
# 3  AAACCCAAGGAGAGTA-1   ABAT                   2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                   2
# Unique UMI counts for UMI length 3:
#               barcode   gene  unique_UMI_count_3
# 0  AAACCCAAGGAGAGTA-1   AAK1                   4
# 1  AAACCCAAGGAGAGTA-1   AAMP                   2
# 2  AAACCCAAGGAGAGTA-1   AATK                   1
# 3  AAACCCAAGGAGAGTA-1   ABAT                   2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                   2
# Unique UMI counts for UMI length 4:
#               barcode   gene  unique_UMI_count_4
# 0  AAACCCAAGGAGAGTA-1   AAK1                   4
# 1  AAACCCAAGGAGAGTA-1   AAMP                   2
# 2  AAACCCAAGGAGAGTA-1   AATK                   1
# 3  AAACCCAAGGAGAGTA-1   ABAT                   2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                   2
# Unique UMI counts for UMI length 5:
#               barcode   gene  unique_UMI_count_5
# 0  AAACCCAAGGAGAGTA-1   AAK1                   4
# 1  AAACCCAAGGAGAGTA-1   AAMP                   2
# 2  AAACCCAAGGAGAGTA-1   AATK                   1
# 3  AAACCCAAGGAGAGTA-1   ABAT                   2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                   2
# Unique UMI counts for UMI length 6:
#               barcode   gene  unique_UMI_count_6
# 0  AAACCCAAGGAGAGTA-1   AAK1                   4
# 1  AAACCCAAGGAGAGTA-1   AAMP                   2
# 2  AAACCCAAGGAGAGTA-1   AATK                   1
# 3  AAACCCAAGGAGAGTA-1   ABAT                   2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                   2
# Unique UMI counts for UMI length 7:
#               barcode   gene  unique_UMI_count_7
# 0  AAACCCAAGGAGAGTA-1   AAK1                   4
# 1  AAACCCAAGGAGAGTA-1   AAMP                   2
# 2  AAACCCAAGGAGAGTA-1   AATK                   1
# 3  AAACCCAAGGAGAGTA-1   ABAT                   2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                   2
# Unique UMI counts for UMI length 8:
#               barcode   gene  unique_UMI_count_8
# 0  AAACCCAAGGAGAGTA-1   AAK1                   4
# 1  AAACCCAAGGAGAGTA-1   AAMP                   2
# 2  AAACCCAAGGAGAGTA-1   AATK                   1
# 3  AAACCCAAGGAGAGTA-1   ABAT                   2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                   2
# Unique UMI counts for UMI length 9:
#               barcode   gene  unique_UMI_count_9
# 0  AAACCCAAGGAGAGTA-1   AAK1                   4
# 1  AAACCCAAGGAGAGTA-1   AAMP                   2
# 2  AAACCCAAGGAGAGTA-1   AATK                   1
# 3  AAACCCAAGGAGAGTA-1   ABAT                   2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                   2
# Unique UMI counts for UMI length 10:
#               barcode   gene  unique_UMI_count_10
# 0  AAACCCAAGGAGAGTA-1   AAK1                    4
# 1  AAACCCAAGGAGAGTA-1   AAMP                    2
# 2  AAACCCAAGGAGAGTA-1   AATK                    1
# 3  AAACCCAAGGAGAGTA-1   ABAT                    2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                    2
# Unique UMI counts for UMI length 11:
#               barcode   gene  unique_UMI_count_11
# 0  AAACCCAAGGAGAGTA-1   AAK1                    4
# 1  AAACCCAAGGAGAGTA-1   AAMP                    2
# 2  AAACCCAAGGAGAGTA-1   AATK                    1
# 3  AAACCCAAGGAGAGTA-1   ABAT                    2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                    2
# Unique UMI counts for UMI length 12:
#               barcode   gene  unique_UMI_count_12
# 0  AAACCCAAGGAGAGTA-1   AAK1                    4
# 1  AAACCCAAGGAGAGTA-1   AAMP                    2
# 2  AAACCCAAGGAGAGTA-1   AATK                    1
# 3  AAACCCAAGGAGAGTA-1   ABAT                    2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                    2
#               barcode   gene  unique_UMI_count_1  unique_UMI_count_2  \
# 0  AAACCCAAGGAGAGTA-1   AAK1                   3                   4
# 1  AAACCCAAGGAGAGTA-1   AAMP                   2                   2
# 2  AAACCCAAGGAGAGTA-1   AATK                   1                   1
# 3  AAACCCAAGGAGAGTA-1   ABAT                   2                   2
# 4  AAACCCAAGGAGAGTA-1  ABCB7                   2                   2
#
#    unique_UMI_count_3  unique_UMI_count_4  unique_UMI_count_5  \
# 0                   4                   4                   4
# 1                   2                   2                   2
# 2                   1                   1                   1
# 3                   2                   2                   2
# 4                   2                   2                   2
#
#    unique_UMI_count_6  unique_UMI_count_7  unique_UMI_count_8  \
# 0                   4                   4                   4
# 1                   2                   2                   2
# 2                   1                   1                   1
# 3                   2                   2                   2
# 4                   2                   2                   2
#
#    unique_UMI_count_9  unique_UMI_count_10  unique_UMI_count_11  \
# 0                   4                    4                    4
# 1                   2                    2                    2
# 2                   1                    1                    1
# 3                   2                    2                    2
# 4                   2                    2                    2
#
#    unique_UMI_count_12
# 0                    4
# 1                    2
# 2                    1
# 3                    2
# 4                    2

# %% [markdown]
# #### 2. Deduplicate to one UMI per cell–gene

# %%
k = 12
# create a k-base UMI column
df[f'UMI_{k}'] = df['UMI'].str[:k]

# now dedupe on that trimmed UMI, not the full one
unique_df_k = df.drop_duplicates(subset=['barcode','gene',f'UMI_{k}'])
print(f"Rows after deduplication (k={k}): {len(unique_df_k)}")
# Out:
# Rows after deduplication (k=12): 15568370

# %% [markdown]
# #### 3. For each gene, count “in how many cells does each UMI appear”

# %%
umi_cell_counts_k = (
    unique_df_k
    .groupby(['gene', f'UMI_{k}'])
    .size()
    .reset_index(name='cell_count')
)
umi_cell_counts_k.head()
# Out:
#    gene        UMI_12  cell_count
# 0  A1BG  AAACTCACTGAG           1
# 1  A1BG  AAACTCCTTAGG           1
# 2  A1BG  AAATACTAGGAT           1
# 3  A1BG  AAATGTCACCCA           1
# 4  A1BG  AAATTATCGTCC           1

# %%
# Compute total UMI–cell appearances per gene
gene_totals_k = (
    umi_cell_counts_k
    .groupby('gene')['cell_count']
    .sum()
)

# Sort descending and take top 30
top30_genes = gene_totals_k.sort_values(ascending=False).head(30).index.tolist()

print("Top 30 genes by total UMI cell appearances:")
for i, g in enumerate(top30_genes, 1):
    print(f"{i:2d}. {g} ({gene_totals_k[g]} total appearances)")
# Out:
# Top 30 genes by total UMI cell appearances:
#  1. MALAT1 (379868 total appearances)
#  2. MT-CO1 (203370 total appearances)
#  3. MT-CO3 (185662 total appearances)
#  4. MT-CO2 (147109 total appearances)
#  5. MT-ATP6 (126052 total appearances)
#  6. EEF1A1 (119826 total appearances)
#  7. MT-ND3 (96831 total appearances)
#  8. MT-ND4 (96204 total appearances)
#  9. B2M (95052 total appearances)
# 10. IGKC (90963 total appearances)
# 11. RPL10 (82954 total appearances)
# 12. MT-CYB (81250 total appearances)
# 13. RPS27 (80994 total appearances)
# 14. TPT1 (79122 total appearances)
# 15. RPL41 (77902 total appearances)
# 16. TMSB4X (77569 total appearances)
# 17. RPL13 (76574 total appearances)
# 18. S100A9 (76181 total appearances)
# 19. RPS12 (71909 total appearances)
# 20. RPLP1 (71475 total appearances)
# 21. MT-ND1 (68004 total appearances)
# 22. ACTB (63064 total appearances)
# 23. RPL39 (57311 total appearances)
# 24. RPL34 (56574 total appearances)
# 25. FTL (54463 total appearances)
# 26. RPS18 (54287 total appearances)
# 27. RPS3A (54145 total appearances)
# 28. LYZ (53903 total appearances)
# 29. RPL30 (53850 total appearances)
# 30. RPL32 (53287 total appearances)

# %% [markdown]
# #### 4. Visualize the UMI‐cell_count distribution for a given gene

# %%
## Plotting “Cells per UMI” Distributions for Multiple Genes

import matplotlib.pyplot as plt
import numpy as np

# List of genes to plot
top_genes = [
    'MALAT1',   # 379868 total appearances
    'MT-CO1',   # 203370 total appearances
    'MT-CO3',   # 185662 total appearances
    'MT-CO2',   # 147109 total appearances
    'MT-ATP6',  # 126052 total appearances
    'EEF1A1',   # 119826 total appearances
    'MT-ND3'    # 96831 total appearances
]

# Number of columns for subplot grid
ncols = 3
nrows = int(np.ceil(len(top_genes) / ncols))

fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 4 * nrows), sharey=True)

for ax, gene in zip(axes.flatten(), top_genes):
    counts = umi_cell_counts_k.loc[umi_cell_counts_k['gene'] == gene, 'cell_count']
    ax.hist(
        counts,
        bins=np.arange(1, counts.max() + 2),
        edgecolor='k'
    )
    ax.set_title(f"{gene} (k={k})")
    ax.set_xlabel("Cells per UMI")
    ax.set_ylabel("Number of UMIs")
    ax.set_yscale('log')

# Turn off any unused subplots
for empty_ax in axes.flatten()[len(top_genes):]:
    empty_ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# For each gene, print its top 10 UMIs by cell_count
for gene in top_genes:
    top_umis = (
        umi_cell_counts_k[umi_cell_counts_k['gene'] == gene]
        .nlargest(10, 'cell_count')      # sort descending by cell_count
        .reset_index(drop=True)
    )
    print(f"\nGene {gene} – Top 10 UMIs (k={k}):")
    print(top_umis[['UMI_' + str(k), 'cell_count']])
# Out:
# Gene MALAT1 – Top 10 UMIs (k=12):
#          UMI_12  cell_count
# 0  TTTTTTTTTTTT          28
# 1  CTTTTTTTTTTT           9
# 2  GTTTTTTTTTTT           8
# 3  TCTTTTTTTTTT           6
# 4  CCCCTTTTTTGT           5
# 5  TATCTTTTTGTT           5
# 6  TTTTTTTTTTTC           5
# 7  ACTATTTTCTTT           4
# 8  AGTTCCTTCCAT           4
# 9  AGTTTTTTCTTT           4
#
# Gene MT-CO1 – Top 10 UMIs (k=12):
#          UMI_12  cell_count
# 0  TTTTTTTTTTTT          14
# 1  GTTTTTTTTTTT           5
# 2  ACTGTGCACGGT           4
# 3  TTTTAGCTTTTT           4
# 4  AATACGCTTAGT           3
# 5  ACGAGTTTTGGT           3
# 6  ATATTTTTTTTG           3
# 7  CAATTTTCGTTT           3
# 8  CTACTCCTGTTT           3
# 9  CTGTTGTGTCTC           3
#
# Gene MT-CO3 – Top 10 UMIs (k=12):
#          UMI_12  cell_count
# 0  TTTTTTTTTTTT          10
# 1  GTTTTTTTTTTT           6
# 2  AATTAGTTAGTA           3
# 3  AATTTTTTTTTT           3
# 4  AGATTTTTTTTT           3
# 5  ATTTGTTTTTTT           3
# 6  ATTTTTTTTTTT           3
# 7  GCTCTTTGTTTG           3
# 8  GGTCTACCTATT           3
# 9  GTATTTTTAGTA           3
#
# Gene MT-CO2 – Top 10 UMIs (k=12):
#          UMI_12  cell_count
# 0  AGTTTTTTTTTT           4
# 1  TCTTTTTTTTTT           4
# 2  TTTTTTTTTTTT           4
# 3  AAGTTCCTTGGT           3
# 4  ATTTTTTTTTTT           3
# 5  CTGGTTTTGTAA           3
# 6  GGTTTTTTAGAT           3
# 7  GTAATATGGATA           3
# 8  GTCTTTTTCTAA           3
# 9  GTTTTTTTTTTT           3
#
# Gene MT-ATP6 – Top 10 UMIs (k=12):
#          UMI_12  cell_count
# 0  TTTTTTTTTTTT           6
# 1  GTTTTTTTTTTT           4
# 2  TATTTTTTTTTT           4
# 3  ATTTTCTTTTTT           3
# 4  CTTATTCACAGG           3
# 5  TACAAATGTTTT           3
# 6  TATTTGTATTTA           3
# 7  AAAACTATATTT           2
# 8  AAACATTGGCTT           2
# 9  AAAGCGTAGAAC           2
#
# Gene EEF1A1 – Top 10 UMIs (k=12):
#          UMI_12  cell_count
# 0  TTTTTTTTTTTT           6
# 1  CTTTTTTTTTTT           4
# 2  AGCTTTTTTTTT           3
# 3  ATAGTTTGGTTT           3
# 4  ATTAATCCTCAG           3
# 5  CATTTTTTTTTT           3
# 6  CCTTTTAGTGGT           3
# 7  CTCATATGGTAT           3
# 8  TCAGCGCTCTAA           3
# 9  TCCTTTTTTTTT           3
#
# Gene MT-ND3 – Top 10 UMIs (k=12):
#          UMI_12  cell_count
# 0  GGTTTTTTTTTT           4
# 1  CTAACAAAATTT           3
# 2  TTATTTCTTAGT           3
# 3  TTTTTTTTTTTT           3
# 4  AAACATCTTCGT           2
# 5  AAACGCTTTGTC           2
# 6  AAACTTGTACTG           2
# 7  AAAGCTGGCGCT           2
# 8  AAAGTAGTTTTT           2
# 9  AAATCAGAAGGT           2

# %%
# 1) Collect all top-10 UMIs into one DataFrame
records = []
for gene in top_genes:
    top_umis = (
        umi_cell_counts_k[umi_cell_counts_k['gene'] == gene]
        .nlargest(10, 'cell_count')
    )
    for _, row in top_umis.iterrows():
        records.append({
            'gene': gene,
            'UMI': row[f'UMI_{k}'],
            'cell_count': row['cell_count']
        })

top10_df = pd.DataFrame(records)

# 2) Find UMIs appearing in more than one gene’s top-10
shared = (
    top10_df
    .groupby('UMI')
    .agg({
        'gene': lambda gs: list(gs),
        'cell_count': lambda cs: list(cs)
    })
    .reset_index()
)

shared = shared[shared['gene'].map(len) > 1]

# 3) Print shared UMIs with their genes and counts
if shared.empty:
    print("No UMIs are shared among the top-10 lists of multiple genes.")
else:
    print("Shared UMIs across top-10 lists:")
    for _, row in shared.iterrows():
        umi_seq = row['UMI']
        pairs = ", ".join(f"{g}({c})" for g, c in zip(row['gene'], row['cell_count']))
        print(f"UMI {umi_seq!r} → {pairs}")
# Out:
# Shared UMIs across top-10 lists:
# UMI 'ATTTTTTTTTTT' → MT-CO3(3), MT-CO2(3)
# UMI 'CTTTTTTTTTTT' → MALAT1(9), EEF1A1(4)
# UMI 'GTTTTTTTTTTT' → MALAT1(8), MT-CO1(5), MT-CO3(6), MT-CO2(3), MT-ATP6(4)
# UMI 'TCTTTTTTTTTT' → MALAT1(6), MT-CO2(4)
# UMI 'TTTTTTTTTTTT' → MALAT1(28), MT-CO1(14), MT-CO3(10), MT-CO2(4), MT-ATP6(6), EEF1A1(6), MT-ND3(3)

# %% [markdown]
# ## More analysis

# %%
# from itertools import combinations

# def hamming(a, b):
#     return sum(x!=y for x, y in zip(a, b))

# #pick pairs with high UMI12 but low UMI5 collapse:
# candidates = final_df[
#     (final_df['unique_UMI_count_12'] < 20) &
#     (final_df['unique_UMI_count_5'] <2)
# ].head(10)

# for _, r in candidates.iterrows():
#     cell, gene = r['barcode'], r['gene']
#     umis = unique_df_k[
#         (unique_df_k['barcode']==cell) &
#         (unique_df_k['gene']==gene)
#     ]['UMI_12'].unique().tolist()
#     print(f"\n{cell}–{gene}: {len(umis)} UMIs → sample: {umis[:10]}")
#     # eyeball these for single-base mismatches
# Out:
# AAACCCAAGGAGAGTA-1–AATK: 1 UMIs → sample: ['ATCTTTCGGGTA']
#
# AAACCCAAGGAGAGTA-1–ABHD13: 1 UMIs → sample: ['GTTGGTGTGCAC']
#
# AAACCCAAGGAGAGTA-1–ABHD15-AS1: 1 UMIs → sample: ['TAAGTCGTGCAC']
#
# AAACCCAAGGAGAGTA-1–ABHD17A: 1 UMIs → sample: ['AGAATTTATTAT']
#
# AAACCCAAGGAGAGTA-1–ABHD6: 1 UMIs → sample: ['GTAACCTAGTCT']
#
# AAACCCAAGGAGAGTA-1–ABL1: 1 UMIs → sample: ['AAAGAAACAGGC']
#
# AAACCCAAGGAGAGTA-1–AC002451.1: 1 UMIs → sample: ['AAAAATCCTACG']
#
# AAACCCAAGGAGAGTA-1–AC002464.1: 1 UMIs → sample: ['GGCTAAGTTGTG']
#
# AAACCCAAGGAGAGTA-1–AC004687.1: 1 UMIs → sample: ['CGCCAGAATTAT']
#
# AAACCCAAGGAGAGTA-1–AC004921.1: 1 UMIs → sample: ['CTCGCCGTTGAC']

# %% [markdown]
# ### Checking for sequencing errors

# %% [markdown]
# ##### 1. Define lengths: Set k_small and k_full = 12
# ##### 2. Filter pairs: Select all (cell, gene) rows from final_df where the 5 base UMI count is exactly 1 but the 12-base UMI count is greater than 1
# ##### 3. Iterate candidates: For each of those filtered cell-gene pairs:

# %%
k_small, k_full = 5, 12
cands = final_df[
    (final_df[f'unique_UMI_count_{k_small}'] == 1) &
    (final_df[f'unique_UMI_count_{k_full}']  > 4)
]

for _, row in cands.iterrows():
    cell, gene = row['barcode'], row['gene']
    umis12 = unique_df_k[
        (unique_df_k['barcode'] == cell) &
        (unique_df_k['gene']    == gene)
    ]['UMI_12'].unique().tolist()
    
    print(f"\n{cell}–{gene}: k=5 count=1, k=12 count={len(umis12)} UMIs → {umis12}")
# Out:
# AAGACAACAGATCACT-1–BRWD1: k=5 count=1, k=12 count=5 UMIs → ['CACAGTCGCTAG', 'CACAGTCGCTAT', 'CACAGTCGCGAG', 'CACAGTCGCGAT', 'CACAGTCGCTCT']
#
# AAGGTAAAGGAAGTAG-1–PAPSS1: k=5 count=1, k=12 count=5 UMIs → ['AGGCGTGTAGTT', 'AGGCGTTTATTT', 'AGGCGTTTTTTT', 'AGGCGTGTATTT', 'AGGCGTTTAGTT']
#
# AATGGAATCTGATGGT-1–ANGEL1: k=5 count=1, k=12 count=5 UMIs → ['CCGGGTCGTTGT', 'CCGGGTCGTGCT', 'CCGGGTCGTTCT', 'CCGGGTCGTTCG', 'CCGGGTCGTGCG']
#
# ACCTACCCAACGGTAG-1–CACYBP: k=5 count=1, k=12 count=5 UMIs → ['GGTCGCTTTGTG', 'GGTCGCGTTGAG', 'GGTCGCGTTGTG', 'GGTCGCTTTGAT', 'GGTCGCTTTGAG']
#
# AGTAACCCAAGCTCTA-1–SERGEF: k=5 count=1, k=12 count=5 UMIs → ['GAGTCGGTTTCG', 'GAGTCGGTTTCC', 'GAGTCGGGTTCG', 'GAGTCGGGGACC', 'GAGTCGGGTACG']
#
# ATAGGCTGTGTTACAC-1–POLA2: k=5 count=1, k=12 count=6 UMIs → ['AGTCGCTTGGAG', 'AGTCGCTTGGTT', 'AGTCGCGTGGCG', 'AGTCGCTTTGAG', 'AGTCGCTTGGTG', 'AGTCGCTTTGTT']
#
# ATGACCACAATATCCG-1–ADIPOR2: k=5 count=1, k=12 count=5 UMIs → ['GTCGTGTTTTTT', 'GTCGTTTTTTTT', 'GTCGTGTTGTTT', 'GTCGTTTTGTTT', 'GTCGTGGTGTTT']
#
# ATGGATCTCGACCTAA-1–CAPN2: k=5 count=1, k=12 count=5 UMIs → ['CCCGGCCGTGGG', 'CCCGGCCGTTCG', 'CCCGGCCGTTCT', 'CCCGGCCGTGGT', 'CCCGGCCGTGCT']
#
# ATGTCCCCATAGGTTC-1–HIPK1: k=5 count=1, k=12 count=5 UMIs → ['TACCGCCGTTTG', 'TACCGCCGTTTC', 'TACCGCCGTGTT', 'TACCGCCGTGTG', 'TACCGCCGTGTC']
#
# CCACGTTTCTGCTGAA-1–ABCC1: k=5 count=1, k=12 count=5 UMIs → ['TCGGGTCGTGTT', 'TCGGGTCGTTTT', 'TCGGGTCGTTTA', 'TCGGGTCGTGTA', 'TCGGGTCGTTGT']
#
# CCCTTAGGTTTCCAAG-1–TMEM123: k=5 count=1, k=12 count=5 UMIs → ['CCCCGGTCGTGG', 'CCCCGGTCGTGT', 'CCCCGGTCGTTC', 'CCCCGGTCGTGC', 'CCCCGGTCGTTG']
#
# CCGGGTACACTCCGAG-1–LYL1: k=5 count=1, k=12 count=6 UMIs → ['AGTCGATTGCCT', 'AGTCGATTGCAT', 'AGTCGATTGGAT', 'AGTCGATTTCAT', 'AGTCGAGTTGAT', 'AGTCGATTTGAT']
#
# CCTGCATGTTCTTAGG-1–SYNCRIP: k=5 count=1, k=12 count=5 UMIs → ['CGGGCGTGTTTT', 'CGGGCGTTTTTT', 'CGGGCGTTTCTT', 'CGGGCGTTTGTT', 'CGGGCGTGTCTT']
#
# CTCCTTTAGATGCTGG-1–PRPF38B: k=5 count=1, k=12 count=6 UMIs → ['AGTCGTGTGACG', 'AGTCGTGTTAAG', 'AGTCGTTTGTAG', 'AGTCGTTTGTCG', 'AGTCGTTTGACG', 'AGTCGTGTGACC']
#
# GATAGCTGTCTGTTAG-1–SUMF2: k=5 count=1, k=12 count=10 UMIs → ['AGTCGTTTTTTA', 'AGTCGTGTTTCA', 'AGTCGTTTGTGA', 'AGTCGTTTTTGC', 'AGTCGTGTGTCA', 'AGTCGTGGGGGC', 'AGTCGTGTGTCC', 'AGTCGTGTTTCC', 'AGTCGTGTGTGA', 'AGTCGTGTGGTA']
#
# GCTGCAGAGGGCAGAG-1–Z97192.3: k=5 count=1, k=12 count=6 UMIs → ['CCGAGTCGCGCT', 'CCGAGTCGCTTG', 'CCGAGTCGCGCG', 'CCGAGTCGCGAT', 'CCGAGTCGCTAG', 'CCGAGTCGCGTG']
#
# GCTTTCGGTTCGGGTC-1–ARL8A: k=5 count=1, k=12 count=5 UMIs → ['ACCGGTCGTGGG', 'ACCGGTCGTTTG', 'ACCGGTCGTGAT', 'ACCGGTCGTTTC', 'ACCGGTCGTGTG']
#
# GGATCTATCACCTACC-1–CTDSP1: k=5 count=1, k=12 count=5 UMIs → ['CCCGTCGCGGGT', 'CCCGTCGCGGTT', 'CCCGTCGCTGAT', 'CCCGTCGCGGCT', 'CCCGTCGCTGTT']
#
# GGGACCTGTTCTTGTT-1–IFI35: k=5 count=1, k=12 count=5 UMIs → ['TTTTTTTTGGTT', 'TTTTTTTGGTTT', 'TTTTTTTTGTTT', 'TTTTTTTTTGGT', 'TTTTTTTTTGTT']
#
# GTAATCGGTTGCGAAG-1–TMEM189: k=5 count=1, k=12 count=5 UMIs → ['ACCGGGCGTTTC', 'ACCGGGCGTGTC', 'ACCGGGCGTGTT', 'ACCGGGCGTGTG', 'ACCGGGCGTTTG']
#
# GTACAACAGATAGCTA-1–PPP2R3C: k=5 count=1, k=12 count=5 UMIs → ['CATCGTCGTTTA', 'CATCGTCGTTTC', 'CATCGTCGTGTC', 'CATCGTCGTGTT', 'CATCGTCGTGTA']
#
# GTGCTTCGTCGCTTGG-1–NMRK1: k=5 count=1, k=12 count=5 UMIs → ['TTACGGTCGTTC', 'TTACGGTCGTGC', 'TTACGGTCGTGT', 'TTACGGTCGTGA', 'TTACGGTCGTTT']
#
# GTGTCCTGTGGCCTCA-1–ZC3H18: k=5 count=1, k=12 count=5 UMIs → ['GAGGCGTGTTTG', 'GAGGCGTTTTGG', 'GAGGCGTTTAGG', 'GAGGCGTGTAGG', 'GAGGCGTGTTGG']
#
# TAGACCAGTCTCGGGT-1–TFG: k=5 count=1, k=12 count=5 UMIs → ['GCCCAGTCGTGC', 'GCCCAGTCGTTC', 'GCCCAGTCGTGA', 'GCCCAGTCGTTG', 'GCCCAGTCGTTA']
#
# TCAATCTGTTTCCCAC-1–TUBA4A: k=5 count=1, k=12 count=5 UMIs → ['CGGCCGCGTTTT', 'CGGCCGCTTTTG', 'CGGCCGCTTTTT', 'CGGCCGCGTATT', 'CGGCCGCGGTTG']
#
# TCCTCCCAGTCTAACC-1–CPNE3: k=5 count=1, k=12 count=5 UMIs → ['CCAGTCGCGTTT', 'CCAGTCGCTTTT', 'CCAGTCGCTTAT', 'CCAGTCGCGTAT', 'CCAGTCGCGGTT']
#
# TGGTAGTCATCACAGT-1–SCAF8: k=5 count=1, k=12 count=5 UMIs → ['TGCCGTCGTGTG', 'TGCCGTCGTGGG', 'TGCCGTCGTTTG', 'TGCCGTCGTGTT', 'TGCCGTCGTTTT']
#
# TGTTCATGTCCTGGGT-1–XRCC5: k=5 count=1, k=12 count=5 UMIs → ['TTAGTTTACTTC', 'TTAGTTTACTTA', 'TTAGTTTAATTC', 'TTAGTGTGCTCC', 'TTAGTGTGCTCT']

# %%
k_small, k_full = 5, 12
cands = final_df[
    (final_df[f'unique_UMI_count_{k_small}'] == 1) &
    (final_df[f'unique_UMI_count_{k_full}']  > 700)
]

for _, row in cands.iterrows():
    cell, gene = row['barcode'], row['gene']
    umis12 = unique_df_k[
        (unique_df_k['barcode'] == cell) &
        (unique_df_k['gene']    == gene)
    ]['UMI_12'].unique().tolist()
    
    print(f"\n{cell}–{gene}: k=5 count=1, k=12 count={len(umis12)} UMIs → {umis12}")

# %%
import random
from itertools import combinations
from collections import Counter

def fraction_hd1(umi_list):
    """Compute fraction of pairs with Hamming distance = 1."""
    total = 0
    hd1 = 0
    for a, b in combinations(umi_list, 2):
        total += 1
        if hamming(a, b) == 1:
            hd1 += 1
    return hd1 / total if total else 0

# Build a lookup of empirical UMI12 frequencies
umi_freq = unique_df_k['UMI_12'].value_counts(normalize=True).to_dict()
umis, probs = zip(*umi_freq.items())

# For each (cell, gene) with, say, ≥ n UMIs, compare to random draw
results = []
for _, row in final_df.iterrows():
    cell, gene = row['barcode'], row['gene']
    n = int(row['unique_UMI_count_12'])
    if n < 100:  # skip small samples
        continue

    # real UMIs
    real_umis = unique_df_k.loc[
        (unique_df_k['barcode']==cell) &
        (unique_df_k['gene']==gene),
        'UMI_12'
    ].unique().tolist()
    real_frac = fraction_hd1(real_umis)

    # synthetic draws
    synth = random.choices(umis, probs, k=n)
    synth_frac = fraction_hd1(synth)

    results.append({
        'cell': cell,
        'gene': gene,
        'n_umis': n,
        'real_hd1_frac': real_frac,
        'synth_hd1_frac': synth_frac
    })

hd1_df = pd.DataFrame(results)

# %%
# how many (cell,gene) points have real_frac > synth_frac?
print((hd1_df['real_hd1_frac'] > hd1_df['synth_hd1_frac']).mean())

# or plot:
hd1_df.plot.scatter('n_umis', 'real_hd1_frac', alpha=0.3, label='real')
hd1_df.plot.scatter('n_umis', 'synth_hd1_frac', alpha=0.3, label='synth')
plt.ylabel("Fraction of UMI pairs at Hamming=1")
plt.legend()

# %% [markdown]
# ### COnusion matrix

# %%
import pandas as pd

k_small, k_full = 5, 12

# Create a DataFrame with only the necessary columns
counts_df = final_df[[
    'barcode', 'gene', 
    f'unique_UMI_count_{k_small}', 
    f'unique_UMI_count_{k_full}'
]].copy()

# Rename columns for easier use
counts_df.columns = ['barcode', 'gene', 'count_k_small', 'count_k_full']

# Filter to include only counts from 1 to 10 (can adjust range if needed)
counts_df = counts_df[
    (counts_df['count_k_small'] <= 10) & (counts_df['count_k_full'] <= 10)
]

# Create the confusion matrix (cross-tabulation)
conf_matrix = pd.crosstab(
    counts_df['count_k_small'], 
    counts_df['count_k_full']
)

# Reindex to ensure all rows/columns 1–10 are present, even if empty
conf_matrix = conf_matrix.reindex(index=range(1,11), columns=range(1,11), fill_value=0)

# Display
conf_matrix
# Out:
# count_k_full        1       2       3       4      5      6      7      8   \
# count_k_small
# 1              2202437  102812    3174     114     23      4      0      0
# 2                    0  758826   72182    4091    220      6      7      0
# 3                    0       0  337408   48415   3880    263     21      2
# 4                    0       0       0  173307  33368   3618    295     30
# 5                    0       0       0       0  98265  23858   3227    316
# 6                    0       0       0       0      0  59618  17647   2908
# 7                    0       0       0       0      0      0  38469  13585
# 8                    0       0       0       0      0      0      0  26143
# 9                    0       0       0       0      0      0      0      0
# 10                   0       0       0       0      0      0      0      0
#
# count_k_full      9      10
# count_k_small
# 1                  0      1
# 2                  0      0
# 3                  3      0
# 4                  2      0
# 5                 27      5
# 6                368     35
# 7               2601    359
# 8              10478   2343
# 9              18259   8437
# 10                 0  13403

# %% [markdown]
# ### Hamming Distance

# %%
# import random
# from itertools import combinations

# def hamming(a, b):
#     return sum(x != y for x, y in zip(a, b))

# def fraction_hd1(umi_list):
#     """Compute fraction of UMI pairs with Hamming distance = 1."""
#     total = 0
#     hd1 = 0
#     for a, b in combinations(umi_list, 2):
#         total += 1
#         if hamming(a, b) == 1:
#             hd1 += 1
#     return hd1 / total if total else 0

# # Step 1: Select 100 random (cell, gene) pairs with UMI_12 count between 2 and 10
# k_full = 12
# lower, upper = 3, 10

# eligible = final_df[
#     (final_df[f'unique_UMI_count_{k_full}'] >= lower) &
#     (final_df[f'unique_UMI_count_{k_full}'] <= upper)
# ]

# cands = eligible.sample(n=min(100, len(eligible)), random_state=42)

# num_available = len(eligible)
# print(f"Number of cell-gene pairs with UMI_{k_full} count between {lower} and {upper}: {num_available}")
# Out:
# Number of cell-gene pairs with UMI_12 count between 3 and 10: 1020785

# %%
# Out:
# ['barcode', 'gene', 'unique_UMI_count_1', 'unique_UMI_count_2', 'unique_UMI_count_3', 'unique_UMI_count_4', 'unique_UMI_count_5', 'unique_UMI_count_6', 'unique_UMI_count_7', 'unique_UMI_count_8', 'unique_UMI_count_9', 'unique_UMI_count_10', 'unique_UMI_count_11', 'unique_UMI_count_12']

# %%
# Out:
# 194
# Computed HD ≤ 2 fraction from 194 sampled UMIs: 0.01650553

# %% [markdown]
# ### Null sample

# %%
import random
from itertools import combinations
import numpy as np

def hamming(a, b):
    return sum(x != y for x, y in zip(a, b))

def fraction_hd_leq2(umi_list):
    total = 0
    close_pairs = 0
    for a, b in combinations(umi_list, 2):
        total += 1
        dist = hamming(a, b)
        if dist <= 2:
            close_pairs += 1
    return close_pairs / total if total else 0

# Extract all unique UMI_12s from the dataset
all_umis = unique_df_k['UMI_12'].unique().tolist()

# Repeat sampling and computation 100 times
n_iterations = 100
hd_leq2_fractions = []

for _ in range(n_iterations):
    sampled_umis = random.sample(all_umis, 500)
    frac = fraction_hd_leq2(sampled_umis)
    hd_leq2_fractions.append(frac)

# Convert to NumPy array if needed
hd_leq2_fractions = np.array(hd_leq2_fractions)

# %% [markdown]
# ## Statistics

# %%
import random
from itertools import combinations
import numpy as np

def hamming(a, b):
    return sum(x != y for x, y in zip(a, b))

def fraction_hd_leq2(umi_list):
    total = 0
    close_pairs = 0
    for a, b in combinations(umi_list, 2):
        total += 1
        dist = hamming(a, b)
        if dist <= 2:
            close_pairs += 1
    return close_pairs / total if total else 0

# Set UMI lengths
k_small, k_full = 5, 12
num = 500

# Step 1: Filter for cell-gene pairs with count_k_full < 10 and |count_k_full - count_k_small| ≥ 2
eligible = final_df[
    (final_df[f'unique_UMI_count_{k_full}'] <= 10) &
    (abs(final_df[f'unique_UMI_count_{k_full}'] - final_df[f'unique_UMI_count_{k_small}']) >= 5)
]

# Step 2: Filter UMIs in unique_df_k to only those from eligible barcode-gene pairs
filtered_umis_df = unique_df_k.merge(
    eligible[['barcode', 'gene']],
    on=['barcode', 'gene'],
    how='inner'
)

# Step 3: Extract all UMIs and attempt to sample 500 (or fewer if not enough)
all_umis = filtered_umis_df['UMI_12'].tolist()
sampled_umis = random.sample(all_umis, num) if len(all_umis) >= num else all_umis

print(len(sampled_umis))

# Step 4: Compute the fraction of UMI pairs with Hamming distance ≤ 2
hd_fraction = fraction_hd_leq2(sampled_umis)
print(f"Computed HD ≤ 2 fraction from {len(sampled_umis)} sampled UMIs: {hd_fraction:.8f}")
# Out:
# 194
# Computed HD ≤ 2 fraction from 194 sampled UMIs: 0.01650553

# %%
p_value_10 = (sum(hd_fraction <= hd_leq2_fractions) + 1) / (n_iterations + 1)
p_value_10
# Out:
# np.float64(0.009900990099009901)

# %% [markdown]
# #### Creating adata matrices from the reads dataframe above

# %%
import pandas as pd
import anndata as ad

# Assuming final_df is already defined
# Initialize a dictionary to store the AnnData objects for each UMI length
adata_dict = {}

# Loop through UMI lengths from 1 to 12
for k in range(1, 13):
    # Select the columns for the current UMI length
    adata_matrix = final_df[['barcode', 'gene', f'unique_UMI_count_{k}']]

    # Pivot the DataFrame to create a matrix with barcodes as rows and genes as columns
    matrix_df = adata_matrix.pivot(index='barcode', columns='gene', values=f'unique_UMI_count_{k}').fillna(0)

    # Convert the DataFrame into an AnnData object, setting barcodes as observation names (obs_names)
    adata = ad.AnnData(X=matrix_df.values)

    # Set the observation names (obs_names) directly to the barcodes
    adata.obs_names = matrix_df.index

    # Set the variable names (var_names) to the actual gene names
    adata.var_names = matrix_df.columns

    # Add the AnnData object to the dictionary with UMI length as the key
    adata_dict[k] = adata

# Example: Print the structure of the AnnData object for UMI length 1
print(adata_dict[1])  # Accessing the AnnData object for UMI length 1.
# Out:
# AnnData object with n_obs × n_vars = 1232 × 28227

# %% [markdown]
# #### Identifying the cells withe most counts

# %%
# Set how many top cells you want
top_barcodes = 1000  # Change this value as needed

# Get the adata matrix for UMI length 12
adata12 = adata_dict[12]

# Sum total counts for each cell
total_counts = adata12.X.sum(axis=1)

# If X is sparse, convert to dense array
if not isinstance(total_counts, np.ndarray):
    total_counts = np.array(total_counts).flatten()

# Get indices of the top N cells
top_indices = np.argsort(total_counts)[::-1][:top_barcodes]

# Get barcodes and their corresponding total counts
top_barcodes_list = adata12.obs_names[top_indices]
top_counts = total_counts[top_indices]

# Print barcode and count side by side
for barcode, count in zip(top_barcodes_list, top_counts):
    print(f"{barcode}: {count:.0f}")

# Save the list of barcodes to a .txt file
with open("bam_file_analysis/1k_PBMCs/ur_objects/top_barcodes.txt", "w") as f:
    for barcode in top_barcodes_list:
        f.write(f"{barcode}\n")
# Out:
# CGAGAAGTCAAGTTGC-1: 81728
# GATCACACACCCTGTT-1: 76516
# CTACAGACAACAAAGT-1: 62465
# GGTTGTATCGAAGGAC-1: 52593
# TCGACCTCAAGTAGTA-1: 47036
# TATCTTGTCCATCTCG-1: 45555
# CAGGTATGTCAGTCTA-1: 39440
# AAGACAACAGATCACT-1: 38973
# CCTCCAAAGGCCCGTT-1: 38770
# TTGTTCACACTTGTGA-1: 38322
# TGTTCATAGCTGCCTG-1: 37878
# CCGATGGGTTCTCGCT-1: 37220
# CACTTCGTCACCTACC-1: 36546
# CGAGAAGTCCAATGCA-1: 35839
# TATCGCCTCTCCCAAC-1: 35569
# TGTTTGTGTGGAAATT-1: 34009
# TCCTCTTAGCCAAGGT-1: 33576
# TCCTTCTCAACTCGTA-1: 33108
# CACTGAATCCTGATAG-1: 32983
# ATGGGAGCACTCCGGA-1: 32872
# GCTTCACCAACACGAG-1: 32677
# TGTCCACTCGCTTACC-1: 32139
# TCTCCGAAGTCAATCC-1: 32053
# CAAGCTAGTGGCTGCT-1: 31781
# GAAGCCCCAGGAACCA-1: 31734
# TCACACCCACCAGCCA-1: 31714
# ACCTGTCTCTCAACGA-1: 31063
# GTGTGGCAGGTACTGG-1: 30713
# ATCACTTGTGGCTGCT-1: 30694
# CGTTAGATCATTATCC-1: 30605
# TCAGCAAGTATGACAA-1: 30604
# GGTGTTAGTGGATTTC-1: 30603
# GTAGTACTCTGTGTGA-1: 30117
# AATGACCGTGTCATCA-1: 29838
# CTCCCTCCACCGGAAA-1: 29607
# GTTAGTGCACCTCTAC-1: 29588
# CCTAAGAAGACTCTAC-1: 29476
# AACGGGAGTCGCTCGA-1: 29249
# CCGAACGAGGAACGCT-1: 28972
# GTCTAGAGTATGTCAC-1: 28958
# TACGCTCTCTCGGTCT-1: 28841
# TTAATCCAGCTACTAC-1: 28499
# ACGTACACAAAGCTCT-1: 28489
# TGAGGTTGTAGCTTTG-1: 28384
# AAAGTCCCACCAGCCA-1: 28373
# CTCCTTTAGATGCTGG-1: 28310
# AAGAACAAGCCTCAGC-1: 28139
# AAGCATCCAGTCTTCC-1: 28060
# CCTCTCCTCGTTCCTG-1: 27963
# CCTGCATAGTGGTGAC-1: 27848
# TGATCAGAGGATTCAA-1: 27822
# ACTTATCTCTAAGGAA-1: 27802
# TGAGGTTCAGGACATG-1: 27782
# CAAGAGGTCTTCACGC-1: 27645
# AAATGGAGTACCGCGT-1: 27631
# GCTTTCGTCTGGGTCG-1: 27630
# ATTTCTGCAAGGTCTT-1: 27453
# AAGCGTTCACTGATTG-1: 27390
# GCAGCTGGTAAGTTAG-1: 27133
# CCACACTCAGGACTTT-1: 26989
# AAAGGATTCCGTTTCG-1: 26937
# AATTCCTTCCATTGGA-1: 26905
# AGGCCACAGGGCCAAT-1: 26749
# TCTGCCAGTAGATGTA-1: 26733
# GCTTGGGAGAAGGTAG-1: 26695
# CACTGGGGTCGCACAC-1: 26550
# TTGCCTGGTAGCTGCC-1: 26542
# CATTTCATCTCTCTTC-1: 26458
# GGGACAATCCGATCTC-1: 26291
# CTCCATGTCGTCGATA-1: 26287
# CCGGGTACACTCCGAG-1: 26155
# TGTGCGGTCACATACG-1: 25918
# GGGACTCCACGGGCTT-1: 25870
# GTGCGTGAGCTTCTAG-1: 25859
# TTACGTTGTTTACGAC-1: 25852
# TCCTTTCTCGCTGTCT-1: 25832
# GTTGAACGTACCCGCA-1: 25725
# ATCTCTACAAGAAACT-1: 25707
# TGAGCGCCAGCATACT-1: 25698
# TCACGGGCAACCGACC-1: 25696
# GCAGCTGTCAAAGCCT-1: 25687
# CTGCTCACAGCGTTTA-1: 25625
# ATCCACCGTTTGTTGG-1: 25588
# ATTCGTTGTGTAGCAG-1: 25567
# TGGGATTGTACGATGG-1: 25509
# TAGTGCACAGAGGAAA-1: 25422
# CACGGGTAGCATTTGC-1: 25306
# ATACTTCGTACGACTT-1: 25197
# ATTCAGGCATAGCTGT-1: 25015
# CAACGATAGCCTAGGA-1: 24967
# TCTTAGTGTTGCCAAT-1: 24965
# CAGGGCTTCGACGAGA-1: 24964
# CCCTAACGTAACTGCT-1: 24927
# CAAGACTTCAATCGGT-1: 24676
# GGGTCACGTCCTTAAG-1: 24511
# TCACATTCAGAACTAA-1: 24400
# GAGTTGTAGCGTTACT-1: 24316
# CTCATTATCGTACACA-1: 24297
# TCACTCGCAAAGCAAT-1: 24264
# TAGGTACGTGTCATCA-1: 24187
# TCACACCGTTAAACCC-1: 24153
# CTGCCATTCGGAACTT-1: 24101
# CGCATAAAGTGATGGC-1: 24069
# AAGTGAATCGGAAGGT-1: 24039
# GCAGTTATCTCTCTTC-1: 24017
# ATCACAGAGACGTCCC-1: 23994
# CCACTTGTCGCAGAGA-1: 23752
# TGTACAGAGACTCGAG-1: 23584
# CTGTGGGGTCGTGATT-1: 23542
# TGGGTTAGTATTGAGA-1: 23520
# TCTCTGGCAAAGCAAT-1: 23514
# CACGTTCCAGCTTCCT-1: 23508
# GACCCTTCAGCGTATT-1: 23448
# CATCGTCTCCGTTGAA-1: 23435
# TGGGCTGAGCGTTAGG-1: 23425
# TAATTCCGTATTGACC-1: 23400
# TAGATCGTCACAACCA-1: 23397
# TCTCCGATCTCTCTTC-1: 23373
# GAGCCTGAGGCAGCTA-1: 23286
# GGAACCCAGCCATTTG-1: 23267
# TGGGAGAAGTGGTGGT-1: 23232
# CACCAAAAGGACATCG-1: 23210
# GTAGTACCACCCTATC-1: 22971
# TGAGCGCCACTATGTG-1: 22902
# TCAGTCCGTAAGATCA-1: 22849
# CATGCCTGTTCCGCAG-1: 22646
# AAGACAACACTTCAGA-1: 22625
# AAATGGAAGCCGCTTG-1: 22618
# CATTGAGAGGGACCAT-1: 22616
# ATCGTCCAGCCTGAAG-1: 22497
# ATTTCACGTGGATACG-1: 22468
# TCAGCAACAAATCAAG-1: 22388
# GCTACCTGTCCTACAA-1: 22369
# TGAGTCACAGAACGCA-1: 22266
# AAATGGACAATGCTCA-1: 22237
# CCACGAGTCTTCCTAA-1: 22234
# AGACTCATCAGAGCGA-1: 22127
# TCATCATAGCACACAG-1: 22098
# TGAATGCTCGACGAGA-1: 22091
# TTGCTGCCATTGCCGG-1: 22070
# TCTATACGTTATCCAG-1: 22032
# TGGGCTGCATCCGATA-1: 21984
# CCTTCAGCACAGAGCA-1: 21907
# TCTTAGTCAACACGAG-1: 21900
# GGGCCATTCAGACCGC-1: 21879
# GATAGCTGTCGGAAAC-1: 21819
# CGTTAGATCAGCCTCT-1: 21720
# TTGGGATTCAGGAAGC-1: 21719
# CAGCAATGTATCGTTG-1: 21707
# GGTAATCTCAAGTTGC-1: 21682
# AAGTTCGGTCAACACT-1: 21564
# GACTATGCATCATTGG-1: 21515
# GTAGAAATCTGAGATC-1: 21456
# CTGGACGTCTCATTTG-1: 21448
# CCGGACAGTGATACCT-1: 21411
# CTCCCTCAGCGCGTTC-1: 21401
# AGACAAAGTAGCTTGT-1: 21401
# AGCCAGCGTAGTTAGA-1: 21271
# AGTCAACGTACACGCC-1: 21271
# GAGACCCAGTAGGATT-1: 21262
# AGGTAGGCAAAGCGTG-1: 21239
# CTCAGGGTCTCACCCA-1: 21161
# TAGACTGTCGCCGAGT-1: 21119
# GTAACACAGCTCCGAC-1: 21084
# GCCTGTTCACAGTCAT-1: 20981
# CCTGTTGGTGTGCCTG-1: 20960
# TCACTCGTCGGTCATA-1: 20902
# ATGTCCCGTCCTACGG-1: 20823
# CGTGCTTCAAGCGCTC-1: 20819
# GCTACCTCACGCACCA-1: 20818
# AAAGGATTCAGCTTGA-1: 20770
# TCATATCCATGCTGCG-1: 20632
# CCTATCGAGACAGCGT-1: 20613
# AACCTGACATCCTATT-1: 20426
# GTTACGAGTATGAGAT-1: 20423
# TTGCATTGTGCCTTCT-1: 20356
# TCCTCTTAGAGTGAAG-1: 20313
# TGTAGACTCCATTTAC-1: 20277
# CTAGACAGTCTAACTG-1: 20175
# AGGTTACGTCTGATAC-1: 20171
# TTGTTCACAGTCGCTG-1: 19976
# GGAATGGAGGACTAAT-1: 19931
# TTTCCTCTCTCTTGCG-1: 19914
# GTAGCTATCTCATGGA-1: 19864
# TCAGTTTAGGATATAC-1: 19767
# TGAGGAGTCCATCGTC-1: 19766
# ATGACCAAGGCTAACG-1: 19721
# CAACGATAGACGGAAA-1: 19682
# GAGCTGCGTCGGATTT-1: 19590
# GCATCGGGTAACGATA-1: 19571
# AGCATCAGTCGGTGTC-1: 19499
# CAGCCAGGTGGGTTGA-1: 19368
# AGGAAATTCACCATGA-1: 19363
# AGTACCAGTGGGTCAA-1: 19349
# CACTGGGAGGCGACAT-1: 19348
# CACGTTCTCTATCACT-1: 19218
# GGACGTCGTTCAACGT-1: 19158
# ATGGTTGTCACGGAGA-1: 19133
# TTGCCTGAGAGTGACC-1: 19117
# CCACGTTTCTGCTGAA-1: 19093
# AACAAGAGTTATAGAG-1: 19039
# CATTCTATCAGTAGGG-1: 19017
# CACAGATCACTCCGAG-1: 18951
# TTACCGCGTCCGAAAG-1: 18876
# TCGGGCATCTGAACGT-1: 18860
# GGTGTCGCAACGATCT-1: 18858
# GACTCAATCTCCCAAC-1: 18846
# TTCCACGGTCAACACT-1: 18773
# GAGACTTCAGGCTATT-1: 18760
# GTCATGAAGTTTGGCT-1: 18744
# TGAATGCTCGCCGTGA-1: 18701
# TTCCTCTGTACCTGTA-1: 18700
# TCACAAGGTGGATACG-1: 18682
# GATGGAGAGCCAGACA-1: 18656
# GCCAACGTCTGCATAG-1: 18594
# ACTATGGAGAAATCCA-1: 18557
# TAGAGTCGTTGTGTAC-1: 18556
# CCTCTAGCAGACCTAT-1: 18536
# AGCCACGGTTCCGCGA-1: 18516
# ACAAAGAAGCCTCAAT-1: 18460
# CACAGATGTTCCGTTC-1: 18328
# CCTCATGTCTCTCAAT-1: 18279
# AATGGAATCTGATGGT-1: 18270
# CGGGTGTTCCGTGACG-1: 18257
# GTAATGCCACCAGTAT-1: 18184
# GGGATGAAGTCCCGAC-1: 18088
# CAGGCCAGTTCAATCG-1: 18072
# CTGCGAGAGTGCACTT-1: 18053
# CATAAGCTCCGTGTGG-1: 18025
# AATGGAACACTCATAG-1: 17953
# TTCGCTGAGGGTTAGC-1: 17902
# TGGGTTATCAGTAGGG-1: 17824
# GAAGGACGTCTGCCTT-1: 17774
# AGTCAACAGTCATGCT-1: 17767
# GGAATCTTCAATCTCT-1: 17708
# TGACCCTTCTCATTGT-1: 17690
# ATTCCTACATGAGATA-1: 17688
# AGCCAATAGTCCCTAA-1: 17661
# ATCGTCCTCGGAGCAA-1: 17657
# TCTATCAGTATGCTAC-1: 17621
# GAAGAATAGGTACAAT-1: 17436
# TGCAGTATCCACATAG-1: 17367
# AAAGGTACAACTGCTA-1: 17346
# GCTTTCGAGTGCAAAT-1: 17311
# AGGTGTTCATTAAGCC-1: 17294
# TCCCACACAGACCAAG-1: 17262
# GTGTCCTCAGTTGTTG-1: 17224
# GGTGATTCAGCTCGGT-1: 17219
# GCGAGAAAGTTGTAGA-1: 17144
# GCTGAATTCGTTAGTG-1: 17013
# TTTATGCGTAACATAG-1: 16996
# TCGTAGACAATGAAAC-1: 16968
# TTGGGATTCTCTCTAA-1: 16952
# CAACGATTCAAGCCCG-1: 16890
# CGGACACAGGACAGCT-1: 16799
# CTGGACGCAACGATTC-1: 16750
# ATTTCACAGTGCAAAT-1: 16741
# TGTACAGAGTGAGTTA-1: 16720
# GTGGAAGAGCCAAGTG-1: 16671
# GGGACCTGTTCTTGTT-1: 16625
# AGAAGCGTCTGCGTCT-1: 16593
# CACGAATCACATAGCT-1: 16499
# TATACCTTCTGTCCGT-1: 16403
# TTTGGTTGTAGAATAC-1: 16323
# TCAGTCCGTCTCTCAC-1: 16314
# AACGTCAAGACGCCCT-1: 16304
# CTCAATTTCGGAAGGT-1: 16192
# TTGCCTGAGTGGAAAG-1: 16190
# CTCAACCGTGGATGAC-1: 16184
# CCTCATGGTTTCGCTC-1: 16171
# TACAGGTTCCTTACCG-1: 16153
# ATGGATCGTAGATTGA-1: 16151
# GCTGCAGGTTGACGGA-1: 16137
# ATCGTCCGTATGAGGC-1: 16108
# TACATTCGTGGCTTAT-1: 16066
# CTACCTGTCTCGAACA-1: 15994
# TCCTCCCAGTCTAACC-1: 15955
# AGGACGATCACTGATG-1: 15903
# TCCCAGTTCGACATAC-1: 15889
# TAGTGCACACTCGATA-1: 15875
# AGACTCATCAACGCTA-1: 15840
# AGGGTTTCAGCGTGCT-1: 15835
# TGAGTCAGTCACTCTC-1: 15785
# ATCACAGCATGACGTT-1: 15734
# GGTCACGCAATGGCCC-1: 15622
# ATACTTCTCAGCTGAT-1: 15599
# TTATTGCGTGTCTTCC-1: 15475
# GGGTCACTCACAAGGG-1: 15449
# ACTGTGACAACTCGAT-1: 15400
# TTTATGCGTTGATCGT-1: 15328
# CCATAAGGTGAGGAAA-1: 15319
# CACTGTCCACATATGC-1: 15300
# GTCCTCAAGTCACGAG-1: 15281
# ATTTCTGTCGGCCAAC-1: 15253
# ATGAAAGTCCTTATGT-1: 15250
# CGATGGCCACTCGATA-1: 15208
# AATCGACGTGAGACGT-1: 15196
# ACAACCATCTGCCCTA-1: 15122
# TGAACGTGTAACTAAG-1: 15075
# CTCCTTTTCTACACTT-1: 15039
# TCAAGCATCCACTTTA-1: 15006
# ACTTTCAGTACGCGTC-1: 14992
# ACCCTTGGTATCGTAC-1: 14925
# TCTGGCTCATCCTGTC-1: 14912
# CAGATTGGTGACTAAA-1: 14861
# TACCTGCAGTCTGCAT-1: 14854
# GCTGCAGAGGGCAGAG-1: 14854
# GGAGGTAAGGCGTTGA-1: 14827
# TCACATTCATGCCATA-1: 14820
# TTGGGTAGTGCTAGCC-1: 14815
# AGTAGTCGTATGACAA-1: 14777
# CAGGCCATCCACTAGA-1: 14776
# TCAGGGCTCATGCGGC-1: 14758
# AGTAGCTGTTAGAAAC-1: 14731
# CCACGTTTCATCAGTG-1: 14721
# CTCCTCCTCACCTCTG-1: 14719
# CTGGACGCACACGGTC-1: 14713
# CAATGACTCAAGCCCG-1: 14693
# GACTATGTCCAAGGGA-1: 14689
# CTCAGGGGTCATCGCG-1: 14685
# TTCCTTCGTGACACGA-1: 14608
# CATCAAGGTATGGTTC-1: 14598
# CTGCCATTCAGTGTTG-1: 14582
# GGTCTGGTCTCCCAAC-1: 14541
# CTGTGAAAGGAACGCT-1: 14537
# CCGATCTGTGGAGGTT-1: 14502
# ACACGCGGTGTTGCCG-1: 14456
# TTTCCTCTCCTACACC-1: 14444
# GAGGGTACAGTTTCAG-1: 14431
# TTACGTTTCTCGCTTG-1: 14426
# AGAGAATCACCCAACG-1: 14426
# TGACTCCCACCATAAC-1: 14402
# GGGTTTACACAGAGCA-1: 14398
# ACCTGAACATGAGAAT-1: 14392
# AAGCGTTTCGCTATTT-1: 14392
# AAACCCAAGGAGAGTA-1: 14309
# ATTCGTTCAGTCTTCC-1: 14271
# TCGTGCTGTGATCATC-1: 14207
# CACAGGCCAACGATCT-1: 14194
# ATTACTCGTTGCAACT-1: 14184
# ACTATCTGTGTGTACT-1: 14179
# ATTTCTGGTATCCTCC-1: 14172
# CCATCACTCTAACACG-1: 14148
# GATCATGAGGCCTAAG-1: 14141
# AAGGTAAAGGCCACCT-1: 14138
# TGCATGAAGCACCCAC-1: 14129
# TGAGCATTCTGTCTCG-1: 14125
# GTAGATCCATCCCGTT-1: 14121
# TCCCAGTAGACCGTTT-1: 14083
# TACGTCCCAAGTGATA-1: 14066
# GACCTTCCACCTGCGA-1: 14039
# GCTGAATAGCACTCTA-1: 14034
# CCGATGGTCTGTCGCT-1: 14021
# CTGGACGGTTCCCAAA-1: 14009
# TCGATTTGTACGCTTA-1: 14001
# TCTTAGTAGGCCTGCT-1: 13996
# GCCAGGTGTTAGAAAC-1: 13958
# CTCAAGAAGATTACCC-1: 13953
# ACCACAAAGGCCTTGC-1: 13925
# CAAAGAAGTTCTCCCA-1: 13897
# CCATCACCATTAAAGG-1: 13882
# CCTCCAACACAATGAA-1: 13871
# ATTCGTTGTAACACCT-1: 13865
# TACACCCTCGACTCCT-1: 13859
# GAACTGTTCTCAAAGC-1: 13842
# CATGCCTCAATTGCTG-1: 13837
# GTGCTGGTCAAACCTG-1: 13822
# GGGAGTAAGCAGGCAT-1: 13821
# GTGAGCCTCTGGAAGG-1: 13813
# TGTCAGACACTCACTC-1: 13785
# CGTGCTTAGCTTTGTG-1: 13764
# TGTCCCAGTCGGTGTC-1: 13743
# GACTGATTCATCCTAT-1: 13740
# CTAACCCCACTTCAAG-1: 13732
# CCTGCATGTTCTTAGG-1: 13719
# GATGGAGCACTTGAAC-1: 13689
# AGTCTCCCAACCGTGC-1: 13665
# TAGACTGGTCTTGAAC-1: 13660
# GTGCTTCAGACCATAA-1: 13654
# CTTCAATGTTGGACTT-1: 13642
# AAAGGATAGTAGACAT-1: 13607
# AGAAGCGGTCTAGATC-1: 13599
# GAGGGTATCTGTCCCA-1: 13579
# CACGAATTCAAGTCGT-1: 13576
# TCTTGCGGTCCAGCCA-1: 13556
# AAGAACATCTTGCAAG-1: 13549
# ATGTCCCCATAGGTTC-1: 13546
# TGTGATGCATTCTCTA-1: 13543
# CTGAATGAGCTCTATG-1: 13479
# CTTCTCTTCCTACAAG-1: 13440
# GAATCACCAGTGGTGA-1: 13439
# TTTCATGTCACTCACC-1: 13419
# GACTTCCTCCTCTAGC-1: 13397
# GAACTGTCATCGAACT-1: 13390
# TCATCATGTTGCACGC-1: 13389
# TTCTCTCGTATCGTAC-1: 13371
# CGAGTGCGTTCCGCGA-1: 13360
# GTCTAGATCGAGAGAC-1: 13358
# TCACGCTTCACTAGCA-1: 13342
# GTAATCGCAGTTTCGA-1: 13342
# ATTCGTTGTTCTTGTT-1: 13327
# TTCCGTGGTTCCAGGC-1: 13310
# ATACCGACACACGGTC-1: 13292
# GGAGGATGTATGAAAC-1: 13274
# TAATTCCGTCAGTCCG-1: 13240
# ACATCGATCTTGGGCG-1: 13208
# GGGTTATCAGCCATTA-1: 13170
# GAGGGATCACTTGGCG-1: 13162
# GCAGCCAGTTGCGTAT-1: 13126
# ACATCCCGTAAGATTG-1: 13116
# CGTGTCTGTCAGTTTG-1: 13099
# GGGCTCATCGCAATTG-1: 13098
# GTTCCGTAGTTGCCCG-1: 13081
# TGGAACTAGCGTCTCG-1: 13074
# GTCAAACCAAGCACCC-1: 13071
# TGACTCCAGTCTCCTC-1: 13056
# TACCTCGCACCCAACG-1: 13041
# GTCACGGCACCGTACG-1: 13039
# TAATTCCCACTCCGGA-1: 13027
# ATGACCACAATATCCG-1: 13022
# ACCCAAAGTTGGGAAC-1: 13013
# ATGGGAGTCCACTGAA-1: 13004
# GGAATCTCAAACTGCT-1: 13002
# ACTCCCATCGTCCTCA-1: 12993
# TCACTCGGTCAACCAT-1: 12940
# GGTAATCCACAGCATT-1: 12934
# CGAGGAACACTGATTG-1: 12931
# TCACACCGTCTCACGG-1: 12919
# AGGAATACAAACTCGT-1: 12917
# CACCGTTCACCCTAGG-1: 12916
# CTCATCGAGAGGCGTT-1: 12900
# AGGACGAAGATTAGTG-1: 12895
# TGTCAGACAACTTGGT-1: 12870
# GAGAGGTTCATAGACC-1: 12863
# GCACGGTAGTAGTCTC-1: 12857
# CTTGAGAAGAATTGCA-1: 12837
# CACACAACAAGAAACT-1: 12824
# CTATCCGAGCTGTTAC-1: 12819
# TGCGGCACAAAGACGC-1: 12814
# TCGCAGGGTTCTAACG-1: 12802
# CCTCAACTCTTAGCCC-1: 12763
# AAGTACCCAAAGAACT-1: 12746
# GCTGCAGGTGCTGATT-1: 12745
# CTCCATGTCATCGTAG-1: 12743
# TCACACCTCTTACCAT-1: 12731
# TGATGGTAGACCCGCT-1: 12727
# GTGTGGCTCACCACAA-1: 12701
# CTCCCAATCAATCAGC-1: 12701
# AGGTTACAGGTGCGAT-1: 12698
# TTTCATGGTGCCTAAT-1: 12693
# CCTCAGTCATGATGCT-1: 12679
# GTTGCTCTCATTTCCA-1: 12678
# TCCGATCTCAAACCTG-1: 12665
# GGGTGAACATAAGCAA-1: 12637
# TTCAGGAGTCTACAAC-1: 12633
# ACGTAACAGGTGCTTT-1: 12633
# GATCAGTAGTGCGCTC-1: 12623
# TCTGTCGCACCAGCGT-1: 12616
# CATTCTAGTAGCTTGT-1: 12614
# CTCATTAAGGAAGTGA-1: 12604
# AACAAAGGTGATGAAT-1: 12596
# CAAGGGAAGAGTCGAC-1: 12585
# CTCACTGCACCTTCCA-1: 12532
# CTCAAGAGTCAAAGAT-1: 12529
# CCAAGCGAGGTTCATC-1: 12526
# GTTAGTGAGAACGTGC-1: 12507
# CTCCAACGTAGTGTGG-1: 12496
# CGATGGCGTAGCGTCC-1: 12488
# GAGTTACAGACGACGT-1: 12480
# CCCTAACCAGGTTCGC-1: 12467
# ACCTGTCTCAAGTCTG-1: 12457
# TCACTATGTTTAGACC-1: 12456
# CTCCAACCAATCTCTT-1: 12403
# GTGTCCTGTGGCCTCA-1: 12353
# TCGCAGGAGATTGACA-1: 12345
# CAACAGTCATCCGTTC-1: 12339
# GATCGTACAGCGCGTT-1: 12311
# GAGACTTAGTCACTCA-1: 12306
# CATAAGCGTAGCGCTC-1: 12291
# CAGATACTCGTTCCCA-1: 12282
# AGGACGATCCAGTACA-1: 12269
# CACTGGGAGTTACTCG-1: 12264
# TAACGACCACATATGC-1: 12218
# TCTGTCGAGACTAGAT-1: 12217
# GATTCTTGTACAGTCT-1: 12207
# TGGTACACAAAGGGTC-1: 12205
# ACATTTCGTTTCTTAC-1: 12200
# GTGTGATCACTACGGC-1: 12194
# TCACAAGGTAGTGGCA-1: 12193
# CACTGAAGTCTTTCTA-1: 12184
# CGTAAGTGTGATAGTA-1: 12170
# GTAGAAACATGGACAG-1: 12150
# CTCCGATTCCTTTAGT-1: 12140
# TCAGGTAGTATGGTAA-1: 12140
# TGCTGAACAGCACAAG-1: 12138
# GAAGTAAGTCTAGATC-1: 12138
# CGAGGCTCAGCATGCC-1: 12121
# GCTGAATCACACGGAA-1: 12110
# CAATCGAAGAGGATCC-1: 12102
# TGTCCCAGTCAGGCAA-1: 12100
# ACGATCAGTCGTTCAA-1: 12087
# TCGGGACTCTAGATCG-1: 12086
# CGGAACCGTTTGCAGT-1: 12069
# CAAGACTAGTGGAAAG-1: 12064
# ACGATCATCCGTTGGG-1: 12058
# CAACGATCAAAGCACG-1: 12050
# ATCGGATAGGAAAGGT-1: 12039
# TGTGCGGGTCGTCGGT-1: 12017
# CCTCCTCTCAAGCGTT-1: 12016
# CAAAGAACAGCTGTTA-1: 12011
# CTAAGTGCACAATGCT-1: 12002
# CACTAAGGTGATAGTA-1: 11980
# TTACTGTCATACATCG-1: 11962
# TGAGCATTCGATACTG-1: 11958
# ATGAGTCTCCAGTTCC-1: 11950
# CCAATTTCAAAGGCTG-1: 11925
# ACGGTCGTCACTACGA-1: 11922
# TTCCGTGCACTCACTC-1: 11898
# TACAACGCATAGATCC-1: 11852
# ATCCGTCCAACTCCCT-1: 11838
# ATGGGAGAGACGTCCC-1: 11835
# ACCCTTGTCATTTCGT-1: 11831
# CCGCAAGGTACCAGAG-1: 11824
# TGCTCGTAGACGAGCT-1: 11823
# ATCTTCACATACTGAC-1: 11814
# AGAGCCCGTCACTCGG-1: 11800
# TCATGCCGTGTCTTAG-1: 11795
# TCACGCTAGGACATCG-1: 11790
# CTCCATGAGACAGCTG-1: 11787
# TTACGCCCACGTCGTG-1: 11786
# GCTTTCGTCCGGTAGC-1: 11754
# ATCCCTGCAATTTCTC-1: 11753
# CGAATTGGTCTGTTAG-1: 11735
# AGGATAAAGAACAAGG-1: 11729
# TGGTAGTCAGGCATGA-1: 11725
# GGTAGAGAGACCAGCA-1: 11717
# TGCTCCACAATCTAGC-1: 11715
# CTGCGAGCAGATTCGT-1: 11710
# TTTGATCTCTTTGGAG-1: 11706
# ACACCAAAGAGTCAGC-1: 11705
# AGAAATGTCATTCGTT-1: 11690
# AGTAGCTAGGAGTACC-1: 11681
# GTCTGTCAGATACGAT-1: 11671
# TGGGATTAGTCACGAG-1: 11663
# ACAGAAAAGTATTAGG-1: 11662
# AAGTTCGAGGATACAT-1: 11657
# AAGACAATCCGCGAGT-1: 11648
# TAGGGTTAGAGAGCGG-1: 11642
# TCCATCGGTTTAGTCG-1: 11636
# CAGATTGAGAACGTGC-1: 11617
# AAAGGGCTCATGCCCT-1: 11612
# AGTTAGCGTACCATAC-1: 11612
# GACCCTTCATCATCTT-1: 11607
# TAGACTGAGATTGTGA-1: 11606
# AGGTAGGAGGAAGTAG-1: 11595
# TATACCTGTTCTCGTC-1: 11593
# CCTCCTCCATTCAGGT-1: 11588
# TGCGATAAGAATCGCG-1: 11584
# ATCGATGGTCAATCTG-1: 11577
# GGGCTACAGACCAAAT-1: 11576
# AAGGTAAGTCCTTAAG-1: 11575
# CGAGTTAGTCGAGTTT-1: 11573
# CCTCCTCAGTCCCGAC-1: 11571
# ATTCTACTCTCGTGAA-1: 11564
# TACGGGCTCAACGAGG-1: 11563
# CTGTCGTAGCTGGCCT-1: 11541
# CCTCAGTTCCGAGCTG-1: 11541
# ATTTCTGTCGATGCAT-1: 11525
# TTCACGCGTTAAGTCC-1: 11503
# ATTCACTAGAAGGCTC-1: 11483
# TAGGAGGGTTCCAGGC-1: 11477
# GCAGCTGTCCTTCTGG-1: 11468
# TCTTGCGCAGAGGAAA-1: 11466
# ACCTACCCAACGGTAG-1: 11448
# GTTGCGGAGCTGCCTG-1: 11444
# GGTAATCCATACCACA-1: 11424
# CATGAGTCACCATTCC-1: 11399
# TCTACCGCAGTCGTTA-1: 11393
# TCGGTCTTCGACATAC-1: 11386
# ATTACTCCAGCTTTGA-1: 11375
# CCGCAAGCATTCAGGT-1: 11364
# AAAGTCCAGCGGGTTA-1: 11358
# AGATAGAGTGACACGA-1: 11354
# CTGCCTATCTTGATTC-1: 11336
# ATTCCCGAGTCACTCA-1: 11322
# ACAAGCTGTAGGTCAG-1: 11314
# TACAACGCAAAGGTTA-1: 11308
# TCGGTCTTCATTGCTT-1: 11304
# GGGAGTATCTTAGCCC-1: 11298
# CTAGACAGTCGTGGTC-1: 11288
# TCAATCTAGAGGTTTA-1: 11283
# AGGTGTTTCGTTACCC-1: 11267
# TTCACGCTCTATCCAT-1: 11267
# TCACGCTTCGGACTGC-1: 11264
# TAAGCACAGAAGCTGC-1: 11248
# AGCCACGCAGGTTCGC-1: 11226
# GTCACTCTCTTGAACG-1: 11201
# GCAGCCAAGAGGTCAC-1: 11180
# CATCCGTGTATCGCTA-1: 11175
# TCGGGCATCCGATTAG-1: 11171
# TTCTTGAGTCTTGCTC-1: 11169
# TACTTCATCATGCCGG-1: 11160
# CTCTCAGGTTAAGCAA-1: 11152
# ATCGATGCAACGGCTC-1: 11141
# CAACCTCGTATCGGTT-1: 11137
# CTGTGAATCATCGCTC-1: 11131
# GCCGTGACATGCCGGT-1: 11128
# GTCACGGAGCGGGTTA-1: 11116
# AACCCAAGTGGGCTTC-1: 11113
# TTATTGCCAAACGGCA-1: 11098
# TACGGGCTCTACCACC-1: 11098
# TAGATCGCAAATGGTA-1: 11088
# CGAAGGATCGACGCGT-1: 11076
# AAAGAACGTCTGCAAT-1: 11066
# CATACTTTCAACGAGG-1: 11066
# GCCAACGTCTAACGCA-1: 11043
# GAGGGTAGTCAACACT-1: 11033
# CACATGAGTTTCGACA-1: 11031
# AGTGCCGCATCTGGGC-1: 11028
# GTGAGGACACAACATC-1: 11018
# TCACGCTGTCTGCCTT-1: 11013
# ATAGGCTGTGTTACAC-1: 11005
# GTGATGTAGACATCAA-1: 10984
# GACACGCGTTCCAAAC-1: 10973
# ACTGATGCACCAGCCA-1: 10972
# TTCACCGCAGCCCAGT-1: 10972
# AAGCATCAGGTCCGAA-1: 10971
# AACAACCCACGCTATA-1: 10952
# TCGACCTCAAAGACTA-1: 10949
# CCCTTAGGTTTCCAAG-1: 10946
# GTAAGTCTCGATTGGT-1: 10925
# TTAGTCTCACGTATAC-1: 10922
# TGAGGGATCAAACGTC-1: 10921
# GATGACTTCGTGGCGT-1: 10916
# GAGATGGCATGTAACC-1: 10908
# GTGGGAACATGAGTAA-1: 10895
# CTCGAGGAGGAAAGGT-1: 10890
# TACGCTCTCTTAAGGC-1: 10883
# GGGTTTACACTAAACC-1: 10872
# GATCCCTAGAGGATGA-1: 10859
# CAGATTGAGCTGAGCA-1: 10849
# TTGGGATCAACGGGTA-1: 10834
# TCAATCTGTTTCCCAC-1: 10817
# TGCGGCAAGTGGTGAC-1: 10817
# GAGCCTGGTCCACGCA-1: 10803
# GATTGGTGTTGAGAGC-1: 10800
# GTGTGGCAGGTAGTCG-1: 10795
# GATCCCTGTAATTAGG-1: 10794
# CGGAACCGTATCACGT-1: 10759
# AAGTACCAGCTCCATA-1: 10752
# TGAGCATTCCTTCACG-1: 10745
# TGAGACTAGGCTGAAC-1: 10742
# GGATCTATCACCTACC-1: 10734
# ACTTCGCAGAACCGCA-1: 10727
# ACAGAAACACCAGCGT-1: 10718
# CGTCAAACAGAATGTA-1: 10715
# ATCTTCAGTCTCTCCA-1: 10713
# AGCTACACAGTCGGAA-1: 10710
# TCGCTTGAGCATTTGC-1: 10692
# TTGTGGATCTAAGAAG-1: 10666
# TACCTGCTCCAAGCTA-1: 10663
# GGTCACGGTCGTGATT-1: 10649
# CTGCAGGAGCCATTGT-1: 10648
# CCACGTTTCGTGAGAG-1: 10641
# GATTTCTTCCTTCAGC-1: 10620
# TTAGGGTGTCACATTG-1: 10611
# GTTGTGATCTCGGTCT-1: 10604
# AAACGCTTCAGCCCAG-1: 10594
# CCTGCATCAACGGGTA-1: 10590
# CCGTAGGTCATACAGC-1: 10581
# GTGCTTCGTCGCTTGG-1: 10563
# CAAAGAACACATATCG-1: 10557
# CATGCCTCAGGCTATT-1: 10557
# CAGGTATGTGTAAATG-1: 10540
# TGGAGGAAGTAGGAAG-1: 10537
# CGGGACTGTTTCACTT-1: 10514
# CTAAGTGGTCCACTCT-1: 10514
# ACGGTTAAGTGCTCAT-1: 10506
# TGATGCACAGGGCTTC-1: 10500
# CAATCGATCCGTACGG-1: 10494
# GTTCCGTCACCCGTAG-1: 10483
# AGGCTGCAGGGCTTCC-1: 10476
# CTCCCTCTCATCGCTC-1: 10470
# TTGACCCTCGTAGTGT-1: 10461
# ACATCGATCTAAGAAG-1: 10431
# TCGACGGTCGAAGTGG-1: 10428
# AGGACGAAGACCTTTG-1: 10416
# AGGTGTTTCAATGCAC-1: 10403
# TGAGCATTCCATTGCC-1: 10396
# TGGATCAGTTCTCCCA-1: 10395
# CTGATCCTCCCTCTAG-1: 10388
# GGCTTGGGTAGATCGG-1: 10388
# GAGAAATCATTGGATC-1: 10385
# GTTCTATCAAATGAGT-1: 10383
# CAATTTCAGATTGCGG-1: 10367
# AGCATCAGTGGTCCGT-1: 10357
# ATTCGTTGTGTTCAGT-1: 10339
# AGCCAGCGTAATGCGG-1: 10338
# ACCATTTCATTGGGAG-1: 10330
# GGGATGAAGGGAGGGT-1: 10325
# GAACACTGTTGGACTT-1: 10325
# AGGAATATCATTACGG-1: 10318
# CTCCGATTCTTTCTAG-1: 10311
# AGATCGTCAGGACTTT-1: 10301
# CCTCATGCACTATGTG-1: 10293
# ATTCTTGGTACAATAG-1: 10288
# TTACTGTGTTAAGGGC-1: 10275
# TGTACAGGTGGATTTC-1: 10275
# ACAAAGAGTTCCATTT-1: 10274
# TCGCAGGGTAGGCTCC-1: 10263
# GTAACACGTAGATGTA-1: 10236
# CTGGCAGTCGTCTCAC-1: 10231
# GGAACCCTCTAATTCC-1: 10215
# GGATCTATCATAAGGA-1: 10213
# TCGCTTGAGAGACAAG-1: 10206
# AGTACCATCAGCTTGA-1: 10199
# TCATCCGTCCAACTGA-1: 10190
# GTTCTATTCTACACTT-1: 10187
# CTAGGTATCTAACGCA-1: 10176
# ACGTAGTCACGCCACA-1: 10165
# GTTCTATCACGTGTGC-1: 10155
# TGTCCTGGTTGGCTAT-1: 10150
# GAACGTTGTCAGGAGT-1: 10150
# GATGACTTCTCTAGGA-1: 10126
# TGTCCCACATACTTTC-1: 10126
# TGTTCATGTCCTGGGT-1: 10114
# GGTGTCGGTGTTATCG-1: 10105
# AGGGCTCCAATACGCT-1: 10095
# GCCGTGACAACGACTT-1: 10086
# TAGGGTTAGGAACATT-1: 10080
# TGTCCACCAACTGGTT-1: 10078
# CCACCATAGGTCATCT-1: 10069
# ATACTTCGTTCGGTAT-1: 10067
# AGGTGTTGTCGATTAC-1: 10066
# CCCGGAATCAAACCCA-1: 10059
# GTGAGTTTCCAATGCA-1: 10058
# ATCCACCCATGTCTAG-1: 10051
# AGATGAACAGGCACAA-1: 10051
# AAGTGAACATCAGCAT-1: 10049
# CGTGCTTGTTTAGACC-1: 10045
# AAGTACCAGCGCCTTG-1: 10037
# TCTGCCAGTAACGCGA-1: 10036
# GGTCTGGTCAGACATC-1: 10033
# GCAGCCACATACATCG-1: 10032
# GATTTCTCAAGTGGGT-1: 10023
# ACGATCATCCACGGAC-1: 10020
# ATTCAGGTCTTCGTGC-1: 10018
# TCTTAGTTCAGAATAG-1: 10013
# TTCGCTGCACTAGTAC-1: 9990
# CCTCCAACAACCCTCT-1: 9975
# ATCTTCATCTCATAGG-1: 9963
# CTTCGGTCACGTTCGG-1: 9954
# GTAATCGGTTGCGAAG-1: 9948
# AGTAACCTCGTTGTAG-1: 9938
# TTCATGTAGGTCATAA-1: 9929
# GGGACTCCACATATCG-1: 9926
# GTATTTCAGAAGAGCA-1: 9925
# GTTGTAGCAGTTCTAG-1: 9925
# TCTTGCGCACTACTTT-1: 9908
# CCGTGAGAGAGGTCAC-1: 9903
# CACAGATCATCATGAC-1: 9898
# GATCAGTAGGAACATT-1: 9887
# CGTGAATAGTCGGCCT-1: 9885
# GATGGAGTCTGCGGCA-1: 9882
# GCGGATCAGCAACTTC-1: 9866
# TCGCTCACAAGATTGA-1: 9854
# GGCTGTGCACGGTGAA-1: 9843
# TCATTGTGTGAGCAGT-1: 9838
# TCATGCCCAAAGCGTG-1: 9834
# ATCCACCCAGCAGTGA-1: 9833
# ACTCCCAAGGTTGGTG-1: 9828
# TGCTTGCGTGAACTAA-1: 9826
# TCATACTTCAGAGCAG-1: 9823
# TTGGTTTCACTGGATT-1: 9822
# GCTTTCGGTTCGGGTC-1: 9819
# GTGAGGACACTTTAGG-1: 9819
# GTTACAGCAAATCAGA-1: 9815
# TCATACTCAGGTACGA-1: 9808
# TATGTTCAGTATGGAT-1: 9802
# AGTTCCCCAAACAGGC-1: 9799
# TGTCCCAAGCTCCATA-1: 9799
# CGATCGGCAATTGGTC-1: 9798
# GCGAGAATCCTCAGAA-1: 9795
# ACTTCGCGTACTCCGG-1: 9781
# CGTGTCTCACAGTACT-1: 9758
# GACAGCCGTATCGTGT-1: 9756
# CGATGCGAGCAGAAAG-1: 9743
# TAGATCGCACACGCCA-1: 9739
# TGGGCTGAGAGGGTCT-1: 9732
# TCCTCGATCTCTCGAC-1: 9731
# GGCTGTGGTCCACATA-1: 9729
# TCTCACGAGGCTCCCA-1: 9707
# CGTCCATGTTTGGAAA-1: 9707
# AGTCTCCGTGAGTCAG-1: 9689
# GGGAGATCACGGGTAA-1: 9689
# GTGCTGGCAGGCTACC-1: 9689
# GCCGATGCATCTTTCA-1: 9681
# AACAGGGGTGGGAGAG-1: 9665
# TGTCCTGGTACTTGTG-1: 9660
# TGAACGTCAAATGAAC-1: 9656
# ACATTTCGTGCCGAAA-1: 9652
# CAACAGTTCGAGCACC-1: 9639
# GATGATCGTGTAACGG-1: 9608
# GGGTCTGTCCCGTTCA-1: 9596
# GATAGCTGTCTGTTAG-1: 9584
# CTCAGAACAATTGTGC-1: 9559
# CAGCGTGTCCATCACC-1: 9540
# GCAGCCATCACCGGGT-1: 9532
# GAGCCTGCAGTCTCTC-1: 9531
# GTCTACCCAGGAAGTC-1: 9525
# TGCAGGCCAGGAATAT-1: 9518
# CAGTTCCCAATCGTCA-1: 9513
# GTGCTTCCACTCATAG-1: 9503
# CTCAAGACATCCTGTC-1: 9503
# TGTGTGATCTGACAGT-1: 9500
# GATGGAGTCTTCCAGC-1: 9495
# TCATGTTAGAGGCGGA-1: 9490
# TAAGCGTTCTGTCGTC-1: 9469
# ACACTGATCTTTCCGG-1: 9459
# ATTCAGGCAAGTATCC-1: 9456
# TATTGCTTCTCGAACA-1: 9449
# GTGAGGAAGCATTGAA-1: 9446
# GTTGAACAGGAACATT-1: 9441
# AGAGAATAGAGGGTCT-1: 9435
# TCGAAGTGTATCAGGG-1: 9433
# CTACGGGTCGTTCAGA-1: 9427
# ATCCATTAGACGCAGT-1: 9415
# AGTTCCCGTTACACTG-1: 9409
# GCAACCGTCGAACGGA-1: 9396
# GCAACCGTCATTTCCA-1: 9383
# GCAGCTGGTGGGTCAA-1: 9371
# TAAGCCATCTGGCCTT-1: 9367
# CAGGGCTAGATTGGGC-1: 9366
# CGAGGCTCAGATCACT-1: 9343
# CTCATCGTCGTACCTC-1: 9332
# CTCTCGATCCATAGGT-1: 9328
# GTGGCGTAGAATAACC-1: 9308
# AAAGTGATCGTACACA-1: 9305
# TCTACCGTCCACGGAC-1: 9296
# GAGTGAGGTCGGCTAC-1: 9293
# AAAGGGCTCCGTAGGC-1: 9292
# CCGTAGGGTTCCCACT-1: 9290
# TTGACCCGTCTCGGGT-1: 9266
# AGAGCAGGTTGAGTCT-1: 9264
# GACACGCCAGTCCGTG-1: 9247
# AGAGCAGTCGCGCTGA-1: 9224
# CTGAATGAGGCGAACT-1: 9217
# CTCCCTCGTTTACGAC-1: 9214
# AAAGGATCACCGGCTA-1: 9206
# TGAGCGCTCGTCTAAG-1: 9202
# ACGTACAAGCTGTTCA-1: 9196
# TCTTGCGAGATGAAGG-1: 9193
# AGATGCTGTGTGGTCC-1: 9180
# AGTTAGCGTTCATCGA-1: 9177
# CTGCATCGTAAGCTCT-1: 9164
# TAGGTACTCGAAGCAG-1: 9153
# GTGGGAAAGGTCGTAG-1: 9147
# CTGCGAGAGATTAGAC-1: 9147
# CATCAAGGTTGTCCCT-1: 9142
# TGAGGTTCAAACTAGA-1: 9131
# GGGCTACAGGCAGTCA-1: 9113
# CCAATTTCATTCGATG-1: 9092
# TGGTAGTTCCCTCATG-1: 9090
# CGAGGAAAGTCGCGAA-1: 9083
# ACACTGATCACTGATG-1: 9074
# GCACGTGTCAGACATC-1: 9063
# ATATCCTGTATGAGCG-1: 9060
# AAGGTAAAGGAAGTAG-1: 9050
# AGCTACAGTCGTTTCC-1: 9044
# CCAATGAAGGTCACTT-1: 9025
# AGACCATCATTACTCT-1: 9024
# GGTGATTAGCTGTACT-1: 9022
# TTTCCTCCACAGAGCA-1: 9021
# GTCGAATCAGAACCGA-1: 9019
# CGTTCTGTCAGCGCAC-1: 9018
# AGGGAGTGTGTCGCTG-1: 9014
# GGGTCACCAGGAGGTT-1: 9011
# CGTGTCTCATGGGTTT-1: 9010
# TGCTCGTTCCCATTTA-1: 9006
# TGGGAAGTCGATTGGT-1: 9005
# GATGCTAGTACAGGTG-1: 9002
# GGAAGTGCAACCCTCT-1: 8999
# AAGAACAAGACCATTC-1: 8996
# CCAAGCGAGCTAATCC-1: 8976
# AAATGGATCCTATTTG-1: 8973
# TCTAACTAGGTCCAGA-1: 8957
# TAAGCACTCACCATAG-1: 8954
# GGGTAGAAGTAGGGTC-1: 8947
# ATTCACTTCTCCGCAT-1: 8932
# ACGTACACAGACGATG-1: 8932
# ATACTTCTCGCCGTGA-1: 8917
# ATGCGATGTTGTAGCT-1: 8892
# ACATGCAGTTGCTTGA-1: 8889
# AGTTAGCAGTCAGGGT-1: 8874
# GTTGCTCAGTTTCGAC-1: 8874
# GCGGAAAGTGTGTCCG-1: 8861
# TGTTGAGTCTCGACCT-1: 8846
# GGGTCTGGTTTGAAAG-1: 8837
# AATGAAGCAGTATGAA-1: 8833
# ACTGATGAGCAGCGAT-1: 8819
# GACCTTCGTCGAGCTC-1: 8759
# TCATTACGTGCATGAG-1: 8746
# TGAATGCGTGGACTAG-1: 8735
# GCCGATGAGTAACCTC-1: 8732
# ACGTAACTCATATGGC-1: 8701
# CACGGGTTCCCGATCT-1: 8697
# TTCGCTGTCGGACTGC-1: 8681
# TCAGGTACAATCGCAT-1: 8664
# CCTGTTGTCAAGAGTA-1: 8663
# GCACGGTCACCCAACG-1: 8654
# TTATTGCGTACGTAGG-1: 8643
# GTAGGTTGTGTTCGTA-1: 8617
# GTTACAGAGTGTAGTA-1: 8610
# AACCCAATCTTACCGC-1: 8606
# GTAGGTTCAGAAGCGT-1: 8598
# ATGATCGGTCGAACAG-1: 8589
# TGTCCCAAGGTCATAA-1: 8581
# TGGTAGTCATCACAGT-1: 8578
# TTCCTTCAGTAGTCAA-1: 8574
# GGCTTGGCACCGAATT-1: 8570
# GGGAGATTCACGGACC-1: 8569
# TTACAGGGTGATTCTG-1: 8545
# ACGTAACTCTTCGATT-1: 8543
# AGGGTCCCAGTAGTTC-1: 8542
# GTCTGTCTCGAGCCTG-1: 8535
# GTCGCGAGTTTACCTT-1: 8522
# TGTGATGAGCGACTGA-1: 8508
# GTCCCATCATGCCGAC-1: 8506
# ACCACAAGTCTGTGGC-1: 8499
# AGTAGCTCAGGCACTC-1: 8499
# CAACAACTCGATACTG-1: 8494
# AACCAACAGCTTGTTG-1: 8492
# GAGTTGTCACGGTGCT-1: 8485
# GAGTGTTGTACGTAGG-1: 8484
# TGGGCGTAGTGGAATT-1: 8412
# CTTCGGTTCCAAGAGG-1: 8410
# GTGGCGTCAATCGAAA-1: 8401
# TCTTTGAGTGGAGAAA-1: 8387
# GAGTGTTCACAAGCTT-1: 8368
# AACCCAACAACTGATC-1: 8362
# GTTTGGAGTGTATACC-1: 8356
# TTGTGTTGTGTGTCCG-1: 8335
# ATGCGATGTGCTCTTC-1: 8318
# GTGTGATTCTTACGTT-1: 8315
# AGGACTTTCCTACCAC-1: 8283
# ATCTCTAGTCGTGGTC-1: 8272
# GTCATGACATTGGATC-1: 8261
# ACACGCGTCGCCGTGA-1: 8259
# TTGGGCGCACGGTGAA-1: 8244
# CGATCGGCAGCGTGAA-1: 8239
# GTACAACAGATAGCTA-1: 8232
# AGTAACCCAAGCTCTA-1: 8216
# GGATGTTAGCCGGATA-1: 8206
# TGCAGTAAGTAGTCCT-1: 8205
# TTACTGTGTAAGAACT-1: 8202
# TTGTTTGAGGTCGACA-1: 8198
# ACAGCCGTCGCTGTTC-1: 8192
# TGCGACGAGCGACAGT-1: 8178
# ATAGACCTCCGCTTAC-1: 8173
# TTTGGTTAGTAACCTC-1: 8170
# TTTCACATCTCAGGCG-1: 8145
# TGGATGTTCACGGGAA-1: 8144
# CGCGTGAGTACAATAG-1: 8121
# TGAGTCAGTAACCCTA-1: 8111
# TCTGCCAAGTTACGGG-1: 8102
# ATTCCATCACGACTAT-1: 8098
# TGACAGTTCGAGATGG-1: 8085
# GATGAGGCAAATGCGG-1: 8083
# ACGTAGTCATTAGGAA-1: 8068
# GCTGGGTAGTACAACA-1: 8052
# TAACTTCGTTGTGGAG-1: 8040
# CAGCAGCTCAGAGTTC-1: 8032
# GGTGGCTGTGCGCTCA-1: 8005
# GCAGTTACACATTCTT-1: 7983
# TTATTGCGTCAACACT-1: 7968
# CGTTCTGTCCCGAACG-1: 7964
# CATCGGGTCGCTACAA-1: 7963
# ACATCGATCTGAGAGG-1: 7951
# TTTGTTGCAATTAGGA-1: 7949
# TATATCCCATGCGTGC-1: 7915
# AGAGAGCAGTTGTCGT-1: 7898
# GAGGCAAAGTCACGAG-1: 7885
# TAGCACAAGTACTCGT-1: 7878
# TGGGCTGGTCGCGGTT-1: 7868
# TTCAGGAAGATTGGGC-1: 7859
# AGCGTCGCATTGACCA-1: 7842
# GAGTTGTAGTGCGTCC-1: 7832
# CAGAGCCGTGCCCGTA-1: 7830
# GCCAGTGAGTCCTACA-1: 7812
# TACGTCCCATGTGTCA-1: 7792
# GATGATCGTATGGAAT-1: 7774
# ACTTTCAAGTATGACA-1: 7770
# CTTGATTAGGTAGGCT-1: 7755
# CCGATGGTCACCTCTG-1: 7735
# AGGTCATTCAAGTCGT-1: 7731
# TGGGAGAAGCAAGTGC-1: 7710
# GGTTCTCCAGGTTCCG-1: 7698
# ACACGCGTCACCTCGT-1: 7697
# CTCAGTCAGGGACAGG-1: 7692
# GTCGAATAGGAGTATT-1: 7690

# %%
# !pwd
# Out:
# /data/dagyeman/cellranger

# %% [markdown]
# #### Saving adata matrices

# %%
import os
# Directory to save AnnData matrices

# For 1k PBMCs
# save_directory = '/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/adata_matrices'
save_directory = '/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/adata_matrices'

# For 10k PBMCs
# save_directory = '/data/dagyeman/cellranger/bam_file_analysis/10k_PBMCs/adata_matrices'

# Ensure the directory exists
os.makedirs(save_directory, exist_ok=True)

# Save each AnnData object from the dictionary
for k, adata in adata_dict.items():
    adata_path = os.path.join(save_directory, f'adata_{k}.h5ad')
    adata.write_h5ad(adata_path)

# Example: Print a confirmation message after saving
print(f"Saved AnnData matrices for UMI lengths 1 to 12 in {save_directory}.")
# Out:
# Saved AnnData matrices for UMI lengths 1 to 12 in /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/adata_matrices.

# %% [markdown]
# ## 2. Modeling

# %% [markdown]
# ##### Load the newly created adata matrices into adata_dict dictionary

# %%
import scanpy as sc
import numpy as np 
import matplotlib.pyplot as plt

# directory = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/adata_matrices/"  # Directory for 1k_PBMCs
directory = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/adata_matrices/"  # Directory for 1k_PBMCs
# directory = "/data/dagyeman/cellranger/bam_file_analysis/10k_PBMCs/adata_matrices/"    # Directory for 10k PBMCS

adata_dict = {}
for i in range(1, 13):
    adata_dict[i] = sc.read_h5ad(directory + f"adata_{i}.h5ad")
    
print(adata_dict[6])
# Out:
# AnnData object with n_obs × n_vars = 1232 × 28227

# %% [markdown]
# #### Modeling to confirm adata objects were created properly (Naive Approach)

# %%
# Define the function f(n, 4^j) = 4^j * (1 - (1 - 1/4^j)^n)
def f(n_vals, j):
    results = []
    for n in n_vals:
        result = 4**j * (1 - (1 - 1 / 4**j)**n)
        results.append(result) 
    return np.array(results)



# Define parameters
 # Example values for n (or x)


i = 12
j = 6
# # NOTE: Load the top_barcodes array from the text file
# top_barcodes = np.loadtxt(f'{resolution}/top_barcodes.txt', dtype=str)



barcode = "CTACAGACAACAAAGT-1" #1k
# barcode = "CAGATTGCAGAGTGAC-1"

# Find the index of the barcode in each AnnData object
index1 = np.where(adata_dict[i].obs_names == barcode)[0][0]
index2 = np.where(adata_dict[j].obs_names == barcode)[0][0]

# Extract the gene counts for the barcode from both AnnData objects
gene_counts1 = adata_dict[i].X[index1].flatten()  # Gene counts for UMI length i (e.g., 12)
gene_counts2 = adata_dict[j].X[index2].flatten()  # Gene counts for UMI length j (e.g., 6)

# Create a boolean mask for gene_counts1 that are greater than or equal to 1
mask = gene_counts1 >= 1 

# Apply the mask to filter gene_counts1 and the corresponding values in gene_counts2
gene_counts1 = gene_counts1[mask]
gene_counts2 = gene_counts2[mask]

# Sort the gene counts based on gene_counts1
sorted_indices = np.argsort(gene_counts1)
sorted_gene_counts1 = gene_counts1[sorted_indices]
sorted_gene_counts2 = gene_counts2[sorted_indices]

# Add 1 to both sorted_gene_counts1 and sorted_gene_counts2 to handle log scale properly
sorted_gene_counts1 = sorted_gene_counts1 + 1
sorted_gene_counts2 = sorted_gene_counts2 + 1

# Create the scatter plot
plt.figure(figsize=(10, 9))
plt.scatter(sorted_gene_counts1, sorted_gene_counts2, alpha=0.5, c='blue', edgecolors='w', s=50, linewidth=0.5, label='Gene Counts')

# Adding the identity line
max_val = max(sorted_gene_counts1.max(), sorted_gene_counts2.max())
# plt.plot([1, max_val], [1, max_val], 'r--', linewidth=3, label='y = x') #1k
plt.plot([1, 10000], [1, 10000], 'r--', linewidth=3, label='y = x') #10k


n_values = np.logspace(0, 4.5, 200)

# Use actual gene counts as n values
f_n_4j = f(n_values, j)

# Plot the y = 4^j asymptotic line
y_asymptotic_value = 4**j
plt.axhline(y=y_asymptotic_value, color='purple', linestyle='-', linewidth=3, label=f'Gene counts threshold (UMI {j})')

# Plot the function values as a line
plt.plot(n_values, f_n_4j, 'g-', linewidth=4, label="Model")

plt.xscale('log')
plt.yscale('log')

plt.xlabel(f'True Gene Counts (UMI Length {i})', fontsize=18)
plt.ylabel(f'Gene Counts (UMI Length {j})', fontsize=18)
# plt.title(f"1k_PBMC: Gene Counts for {barcode}")
plt.grid(True, linestyle='-', linewidth=0.5, color='gray', alpha=0.7)
plt.legend(fontsize=16)

plt.show()

# %% [markdown]
# #### Saving the naive modeling plots

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Your model function
def f(n_vals, j):
    return 4**j * (1 - (1 - 1 / 4**j)**n_vals)

# Fixed UMI length for "true" counts
i = 12
barcode = "CTACAGACAACAAAGT-1"
n_values = np.logspace(0, 4.5, 200)

# Output directory
# save_dir = "/data/dagyeman/cellranger/bam_file_analysis/figures_ub/counts_plots/naive"
save_dir = "/data/dagyeman/cellranger/bam_file_analysis/figures_ur/counts_plots/naive"
os.makedirs(save_dir, exist_ok=True)

# Loop through j from 1 to 11
for j in range(1, 13):
        # Find the barcode index
        index_i = np.where(adata_dict[i].obs_names == barcode)[0][0]
        index_j = np.where(adata_dict[j].obs_names == barcode)[0][0]

        # Extract and process counts
        gene_counts_i = adata_dict[i].X[index_i].flatten()
        gene_counts_j = adata_dict[j].X[index_j].flatten()

        mask = gene_counts_i >= 1
        gene_counts_i = gene_counts_i[mask]
        gene_counts_j = gene_counts_j[mask]

        sorted_idx = np.argsort(gene_counts_i)
        sorted_gene_counts_i = gene_counts_i[sorted_idx] + 1
        sorted_gene_counts_j = gene_counts_j[sorted_idx] + 1

        # Create plot
        plt.figure(figsize=(10, 9))
        plt.scatter(sorted_gene_counts_i, sorted_gene_counts_j, alpha=0.5, 
                    c='#1f77b4', edgecolors='w', s=50, linewidth=0.5, label='Gene Counts')
        
        y_asymptotic_value = 4**j
        plt.axhline(y=y_asymptotic_value, color='#984ea3', linestyle='-', linewidth=3, label=f'Gene counts threshold (UMI {j})')
        
        model_vals = f(n_values, j)
        plt.plot(n_values, model_vals, color='#ff7f0e', linewidth=4, label='Model')
        max_val = max(sorted_gene_counts1.max(), sorted_gene_counts1.max())
        plt.plot([1, max_val], [1, max_val], linestyle='--', color='#4D4D4D', linewidth=3, label='y = x')

        plt.xscale('log')
        plt.yscale('log')
        plt.xlabel('True Gene Counts (UMI Length 12)', fontsize=18)
        plt.ylabel(f'Gene Counts (UMI Length {j})', fontsize=18)
        plt.grid(True, linestyle='-', linewidth=0.5, color='gray', alpha=0.7)
        plt.legend(fontsize=16)
        plt.tight_layout()

        # Save plot
        plt.savefig(f"{save_dir}/UMI_12_vs_{j}.pdf")
        plt.show()
        plt.close()

# %% [markdown]
# #### Inverting each adata[i] matrix to predict adata[12] and saving newly generated matrices

# %%
import numpy as np
import scanpy as sc
import anndata

def mom_estimator(y, K):
    # Convert input to a NumPy array (if not already)
    y = np.array(y)
    
    # Preallocate a result array of floats with the same shape as y.
    result = np.empty_like(y, dtype=float)
    
    # First, handle the special case: where y == K.
    special_mask = (y == K)
    if special_mask.any():
        # Compute the special value using the recursive formula.
        special_value = mom_estimator(K - 1, K) + K
        result[special_mask] = special_value
    
    # Then, compute the original (general) case only for entries where y != K.
    general_mask = ~special_mask
    if general_mask.any():
        denominator = np.log(1 - 1/K)
        result[general_mask] = np.log(1 - y[general_mask] / K) / denominator
    
    return result

for k in range(1, 13):
    
    # filepath = f"/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/adata_matrices/adata_{k}.h5ad"
    # output_filepath = f"/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/inverted2_adata_matrices/adata_inverted_{k}.h5ad"
    
    filepath = f"/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/adata_matrices/adata_{k}.h5ad"
    output_filepath = f"/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_{k}.h5ad"
    
    # filepath = f"/data/dagyeman/cellranger/bam_file_analysis/10k_PBMCs/adata_matrices/adata_{k}.h5ad"
    # output_filepath = f"/data/dagyeman/cellranger/bam_file_analysis/10k_PBMCs/inverted2_adata_matrices/adata_inverted_{k}.h5ad"

    adata = sc.read_h5ad(filepath)
    original_matrix = adata.X.copy()  # If sparse, consider converting to dense with .toarray()

    K_val = 4 ** k
    predicted_gex = mom_estimator(original_matrix, K_val)

    new_adata = anndata.AnnData(X=predicted_gex, obs=adata.obs.copy(), var=adata.var.copy())
    new_adata.write_h5ad(output_filepath)

    print(f"New predicted gene expression matrix saved for UMI length {k} to: {output_filepath}")
# Out:
# New predicted gene expression matrix saved for UMI length 1 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_1.h5ad
# New predicted gene expression matrix saved for UMI length 2 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_2.h5ad
# New predicted gene expression matrix saved for UMI length 3 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_3.h5ad
# New predicted gene expression matrix saved for UMI length 4 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_4.h5ad
# New predicted gene expression matrix saved for UMI length 5 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_5.h5ad
# New predicted gene expression matrix saved for UMI length 6 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_6.h5ad
# New predicted gene expression matrix saved for UMI length 7 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_7.h5ad
# New predicted gene expression matrix saved for UMI length 8 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_8.h5ad
# New predicted gene expression matrix saved for UMI length 9 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_9.h5ad
# New predicted gene expression matrix saved for UMI length 10 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_10.h5ad
# New predicted gene expression matrix saved for UMI length 11 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_11.h5ad
# New predicted gene expression matrix saved for UMI length 12 to: /data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/adata_inverted_12.h5ad

# %% [markdown]
# #### Load the inverted adata matrices

# %%
import scanpy as sc
import numpy as np 
import matplotlib.pyplot as plt

# directory = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/inverted2_adata_matrices/"  # Directory for 1k_PBMCs
directory = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/"  # Directory for 1k_PBMCs
# directory = "/data/dagyeman/cellranger/bam_file_analysis/10k_PBMCs/inverted2_adata_matrices/"    # Directory for 10k PBMCS

adata_dict = {}
for i in range(1, 13):
    adata_dict[i] = sc.read_h5ad(directory + f"adata_inverted_{i}.h5ad")
    
print(adata_dict[6])


# Load the ground truth vector 
# adata_12 = sc.read_h5ad("/data/dagyeman/cellranger/bam_file_analysis/10k_PBMCs/adata_matrices/adata_12.h5ad")
# adata_12 = sc.read_h5ad("/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/adata_matrices/adata_12.h5ad")
adata_12 = sc.read_h5ad("/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/adata_matrices/adata_12.h5ad")
adata_12
# Out:
# AnnData object with n_obs × n_vars = 1232 × 28227
# AnnData object with n_obs × n_vars = 1232 × 28227

# %% [markdown]
# ### Saving Model Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

save_dir = "/data/dagyeman/cellranger/bam_file_analysis/figures_ur/counts_plots/model"

# Define the function f(n, 4^j) = 4^j * (1 - (1 - 1/4^j)^n)
def f(n_vals, j):
    results = []
    for n in n_vals:
        result = 4**j * (1 - (1 - 1 / 4**j)**n)
        results.append(result) 
    return np.array(results)

# Define parameters
n_values = np.logspace(0, 4.5, 200)  # Example values for n (or x)
barcode = "CTACAGACAACAAAGT-1" # 1k dataset
# barcode = "CAGATTGCAGAGTGAC-1" # 10k dataset 


# Loop over j values from 1 to 12
for j in range(1,13):
    # Find the index of the barcode in each AnnData object
    index1 = np.where(adata_12.obs_names == barcode)[0][0]
    index2 = np.where(adata_dict[j].obs_names == barcode)[0][0]

    # Extract the gene counts for the barcode from both AnnData objects
    gene_counts1 = adata_12.X[index1].flatten()  # Gene counts for UMI length i (e.g., 12)
    gene_counts2 = adata_dict[j].X[index2].flatten()  # Gene counts for UMI length j

    # Create a boolean mask for gene_counts1 that are greater than or equal to 1
    mask = gene_counts1 >= 1 

    # Apply the mask to filter gene_counts1 and the corresponding values in gene_counts2
    gene_counts1 = gene_counts1[mask]
    gene_counts2 = gene_counts2[mask]

    # Sort the gene counts based on gene_counts1
    sorted_indices = np.argsort(gene_counts1)
    sorted_gene_counts1 = gene_counts1[sorted_indices]
    sorted_gene_counts2 = gene_counts2[sorted_indices]

    # Add 1 to both sorted_gene_counts1 and sorted_gene_counts2 to handle log scale properly
    sorted_gene_counts1 = sorted_gene_counts1 + 1
    sorted_gene_counts2 = sorted_gene_counts2 + 1

    # Create the scatter plot
    plt.figure(figsize=(10, 9))
    plt.scatter(sorted_gene_counts1, sorted_gene_counts2, alpha=0.5, c='#1f77b4', edgecolors='w', s=50, linewidth=0.5, label='Gene Counts')

    # Adding the identity line
    max_val = max(sorted_gene_counts1.max(), sorted_gene_counts2.max())
    plt.plot([1, max_val], [1, max_val], linestyle='--', color='#4D4D4D', linewidth=3, label='y = x')

    # Calculate function values for plotting
    f_n_4j = f(n_values, j)

    # Plot the y = 4^j asymptotic line
    # y_asymptotic_value = 4**j
    # plt.axhline(y=y_asymptotic_value, color='purple', linestyle='-', linewidth=3, label=f'Gene counts threshold (UMI {j})')

    # Plot the function values as a line
    # plt.plot(n_values, f_n_4j, 'g-', linewidth=4, label="Model")

    # Log scale for both axes
    plt.xscale('log')
    plt.yscale('log')

    # Labels and legend
    plt.xlabel('True Gene Counts (UMI Length 12)', fontsize=18)
    plt.ylabel(f'Predicted Counts (UMI Length {j})', fontsize=18)
    # plt.title(f'Inverted Plot vs. Ground Truth (UMI {j})')
    plt.legend(fontsize=16)

    plt.savefig(f"{save_dir}/UMI_12_vs_{j}.pdf")
    # Show the plot
    plt.show()

# %% [markdown]
# ## 3. MAE and MSE Calculations

# %% [markdown]
# ### MAE and MSE for Model (1k dataset)

# %%
import scanpy as sc
import numpy as np

# --- Function Definitions ---
def calculate_mae(actual, predicted):
    """Calculate Mean Absolute Error (MAE) between two arrays."""
    return np.mean(np.abs(actual - predicted))

def calculate_mse(actual, predicted):
    """Calculate Mean Squared Error (MSE) between two arrays."""
    return np.mean((actual - predicted) ** 2)

def f(n_vals, j):
    """Transformation: f(n, 4^j) = 4^j * (1 - (1 - 1/4^j)^n)."""
    return 4**j * (1 - (1 - 1 / 4**j)**n_vals)

# --- Parameters ---
i = 12  # Ground truth UMI length (adata_12)
j = 5   # UMI length for comparison

# --- Load Datasets ---
# Ground truth dataset (UMI length 12)
# adata_12 = sc.read_h5ad("/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/adata_matrices/adata_12.h5ad")
adata_12 = sc.read_h5ad("/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/adata_matrices/adata_12.h5ad")
print("Ground Truth adata_12:")
print(adata_12)

# Inverted dataset for model approach (UMI lengths 1-12)
# model_dir = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/inverted2_adata_matrices/"
model_dir = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/"
adata_dict_model = {idx: sc.read_h5ad(model_dir + f"adata_inverted_{idx}.h5ad") for idx in range(1, 13)}
print("Model Dataset (example adata_dict_model[6]):")
print(adata_dict_model[6])

# Naive dataset (UMI lengths 1-12)
# naive_dir = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/adata_matrices/"
naive_dir = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/adata_matrices/"
adata_dict_naive = {idx: sc.read_h5ad(naive_dir + f"adata_{idx}.h5ad") for idx in range(1, 13)}
print("Naive Dataset (example adata_dict_naive[6]):")
print(adata_dict_naive[6])

# --- Compute Bulk MAE for the Model Approach ---
# Use ground truth counts from adata_12 and predicted counts from the model (inverted) dataset at UMI length j.
all_true_model = []
all_pred_model = []

for barcode in adata_12.obs_names:
    if barcode in adata_dict_model[j].obs_names:
        idx_12 = np.where(adata_12.obs_names == barcode)[0][0]
        idx_j = np.where(adata_dict_model[j].obs_names == barcode)[0][0]
        
        # Extract ground truth counts from adata_12 and predicted counts from the model dataset
        gene_counts_12 = adata_12.X[idx_12].flatten()
        gene_counts_model = adata_dict_model[j].X[idx_j].flatten()
        
        # Only consider genes with counts ≥ 1 and adjust by adding 1 (for log scale)
        mask = gene_counts_12 >= 1
        true_counts = gene_counts_12[mask] + 1
        pred_counts = gene_counts_model[mask] + 1
        
        all_true_model.extend(true_counts)
        all_pred_model.extend(pred_counts)

all_true_model = np.array(all_true_model)
all_pred_model = np.array(all_pred_model)
bulk_mae_model = calculate_mae(all_true_model, all_pred_model)
bulk_mse_model = calculate_mse(all_true_model, all_pred_model)
print("Bulk Model MAE (Ground Truth adata_12 vs. Inverted UMI 5):", bulk_mae_model)


# --- Compute Bulk MAE for the Naive Approach ---
# Use ground truth counts from adata_12 and predicted counts from the naive dataset at UMI length j.
all_true_naive = []
all_naive_pred = []

for barcode in adata_12.obs_names:
    if barcode in adata_dict_naive[j].obs_names:
        idx_12 = np.where(adata_12.obs_names == barcode)[0][0]
        idx_j = np.where(adata_dict_naive[j].obs_names == barcode)[0][0]
        
        # Extract ground truth counts from adata_12 and predicted counts from the naive dataset
        gene_counts_12 = adata_12.X[idx_12].flatten()
        gene_counts_naive = adata_dict_naive[j].X[idx_j].flatten()
        
        # Only consider genes with counts ≥ 1 and adjust by adding 1 (for log scale)
        mask = gene_counts_12 >= 1
        true_counts = gene_counts_12[mask] + 1
        naive_counts = gene_counts_naive[mask] + 1
        
        all_true_naive.extend(true_counts)
        all_naive_pred.extend(naive_counts)

all_true_naive = np.array(all_true_naive)
all_naive_pred = np.array(all_naive_pred)
bulk_mae_naive = calculate_mae(all_true_naive, all_naive_pred)
bulk_mse_naive = calculate_mse(all_true_naive, all_naive_pred)
print("Bulk Naive MAE (Ground Truth adata_12 vs. Naive UMI 5):", bulk_mae_naive)


print("Bulk Model MSE (Ground Truth adata_12 vs. Inverted UMI 5):", bulk_mse_model)
print("Bulk Naive MSE (Ground Truth adata_12 vs. Naive UMI 5):", bulk_mse_naive)
# Out:
# Ground Truth adata_12:
# AnnData object with n_obs × n_vars = 1232 × 28227
# Model Dataset (example adata_dict_model[6]):
# AnnData object with n_obs × n_vars = 1232 × 28227
# Naive Dataset (example adata_dict_naive[6]):
# AnnData object with n_obs × n_vars = 1232 × 28227
# Bulk Model MAE (Ground Truth adata_12 vs. Inverted UMI 5): 0.2054454353838581
# Bulk Naive MAE (Ground Truth adata_12 vs. Naive UMI 5): 0.2697773071618592
# Bulk Model MSE (Ground Truth adata_12 vs. Inverted UMI 5): 44.35100321178493
# Bulk Naive MSE (Ground Truth adata_12 vs. Naive UMI 5): 193.53871096058873

# %% [markdown]
# ### Compare MAE and MSE across Cells (1k)

# %%
import scanpy as sc
import numpy as np

# --- Function Definitions ---
def calculate_mae(actual, predicted):
    """Calculate Mean Absolute Error (MAE) between two arrays."""
    return np.mean(np.abs(actual - predicted))

def calculate_mse(actual, predicted):
    """Calculate Mean Squared Error (MSE) between two arrays."""
    return np.mean((actual - predicted) ** 2)

def f(n_vals, j):
    """Transformation: f(n, 4^j) = 4^j * (1 - (1 - 1/4^j)^n)."""
    return 4**j * (1 - (1 - 1 / 4**j)**n_vals)

# --- Parameters ---
i = 12  # UMI length for ground truth
j = 5   # UMI length for comparison

# --- Load Datasets ---
# Ground truth dataset (UMI length 12)
# adata_12 = sc.read_h5ad("/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/adata_matrices/adata_12.h5ad")
adata_12 = sc.read_h5ad("/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/adata_matrices/adata_12.h5ad")
print("Ground Truth adata_12:")
print(adata_12)

# Inverted dataset for model MAE and MSE (UMI lengths 1-12)
# model_dir = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/inverted2_adata_matrices/"
model_dir = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/inverted2_adata_matrices/"
adata_dict_model = {idx: sc.read_h5ad(model_dir + f"adata_inverted_{idx}.h5ad") for idx in range(1, 13)}
print("Model Dataset (inverted), example adata_dict_model[6]:")
print(adata_dict_model[6])

# Naive dataset (UMI lengths 1-12)
# naive_dir = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ub_objects/adata_matrices/"
naive_dir = "/data/dagyeman/cellranger/bam_file_analysis/1k_PBMCs/ur_objects/adata_matrices/"
adata_dict_naive = {idx: sc.read_h5ad(naive_dir + f"adata_{idx}.h5ad") for idx in range(1, 13)}
print("Naive Dataset, example adata_dict_naive[6]:")
print(adata_dict_naive[6])

# --- Compute Per-cell MAE for the Model Approach ---
mae_model_vector = []
for barcode in adata_12.obs_names:
    if barcode in adata_dict_model[j].obs_names:
        idx_12 = np.where(adata_12.obs_names == barcode)[0][0]
        idx_j = np.where(adata_dict_model[j].obs_names == barcode)[0][0]
        gene_counts_12 = adata_12.X[idx_12].flatten()
        gene_counts_j = adata_dict_model[j].X[idx_j].flatten()
        mask = gene_counts_12 >= 1
        true_counts = gene_counts_12[mask] + 1  # Adjust for log scale
        predicted_counts = gene_counts_j[mask] + 1  # Adjust for log scale
        
        mae_model_vector.append(calculate_mae(true_counts, predicted_counts))
mae_model_vector = np.array(mae_model_vector)
print("Per-cell Model MAE Vector:")
print(mae_model_vector)

# --- Compute Per-cell MSE for the Model Approach ---
mse_model_vector = []
for barcode in adata_12.obs_names:
    if barcode in adata_dict_model[j].obs_names:
        idx_12 = np.where(adata_12.obs_names == barcode)[0][0]
        idx_j = np.where(adata_dict_model[j].obs_names == barcode)[0][0]
        gene_counts_12 = adata_12.X[idx_12].flatten()
        gene_counts_j = adata_dict_model[j].X[idx_j].flatten()
        mask = gene_counts_12 >= 1
        true_counts = gene_counts_12[mask] + 1  # Adjust for log scale
        predicted_counts = gene_counts_j[mask] + 1  # Adjust for log scale
        
        mse_model_vector.append(calculate_mse(true_counts, predicted_counts))
mse_model_vector = np.array(mse_model_vector)
print("Per-cell Model MSE Vector:")
print(mse_model_vector)

# --- Compute Per-cell MAE for the Naive Approach ---
naive_mae_vector = []
for barcode in adata_dict_naive[i].obs_names:
    if barcode in adata_dict_naive[j].obs_names:
        idx_i = np.where(adata_dict_naive[i].obs_names == barcode)[0][0]
        idx_j = np.where(adata_dict_naive[j].obs_names == barcode)[0][0]
        gene_counts_i = adata_dict_naive[i].X[idx_i].flatten()
        gene_counts_j = adata_dict_naive[j].X[idx_j].flatten()
        mask = gene_counts_i >= 1
        true_counts = gene_counts_i[mask] + 1  # Adjust for log scale
        naive_counts = gene_counts_j[mask] + 1  # Adjust for log scale
        naive_mae_vector.append(calculate_mae(true_counts, naive_counts))
naive_mae_vector = np.array(naive_mae_vector)
print("Per-cell Naive MAE Vector:")
print(naive_mae_vector)

# --- Compute Per-cell MSE for the Naive Approach ---
naive_mse_vector = []
for barcode in adata_dict_naive[i].obs_names:
    if barcode in adata_dict_naive[j].obs_names:
        idx_i = np.where(adata_dict_naive[i].obs_names == barcode)[0][0]
        idx_j = np.where(adata_dict_naive[j].obs_names == barcode)[0][0]
        gene_counts_i = adata_dict_naive[i].X[idx_i].flatten()
        gene_counts_j = adata_dict_naive[j].X[idx_j].flatten()
        mask = gene_counts_i >= 1
        true_counts = gene_counts_i[mask] + 1  # Adjust for log scale
        naive_counts = gene_counts_j[mask] + 1  # Adjust for log scale
        naive_mse_vector.append(calculate_mse(true_counts, naive_counts))
naive_mse_vector = np.array(naive_mse_vector)
print("Per-cell Naive MSE Vector:")
print(naive_mse_vector)
# Out:
# Ground Truth adata_12:
# AnnData object with n_obs × n_vars = 1232 × 28227
# Model Dataset (inverted), example adata_dict_model[6]:
# AnnData object with n_obs × n_vars = 1232 × 28227
# Naive Dataset, example adata_dict_naive[6]:
# AnnData object with n_obs × n_vars = 1232 × 28227
# Per-cell Model MAE Vector:
# [0.19673448 0.16378159 0.16216579 ... 0.15343375 0.16428822 0.14403862]
# Per-cell Model MSE Vector:
# [0.87274095 0.52585383 0.76272493 ... 1.298555   0.5039787  0.37107207]
# Per-cell Naive MAE Vector:
# [0.22857143 0.18307826 0.17902996 ... 0.17912553 0.20335525 0.15905849]
# Per-cell Naive MSE Vector:
# [2.03956044 1.19607277 2.04850214 ... 3.36812412 1.58127409 0.65121255]

# %%
import matplotlib.pyplot as plt

# --- MAE Plot ---
plt.figure(figsize=(10, 8))
plt.scatter(naive_mae_vector, mae_model_vector, alpha=0.7, edgecolor='k', s=50)
plt.xlabel("Naïve MAE per Cell", fontsize=14)
plt.ylabel("Model MAE per Cell", fontsize=14)
plt.title("Per-cell MAE: Naïve vs Model", fontsize=16)

# Identity line for reference
min_val = min(naive_mae_vector.min(), mae_model_vector.min())
max_val = max(naive_mae_vector.max(), mae_model_vector.max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='y = x')
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.xscale('log')
plt.yscale('log')

# Save the MAE plot image
# plt.savefig("/data/dagyeman/cellranger/bam_file_analysis/figures_ub/mae_mse_plots/1k_per_cell_mae_naive_vs_model.pdf")
plt.savefig("/data/dagyeman/cellranger/bam_file_analysis/figures_ur/mae_mse_plots/1k_per_cell_mae_naive_vs_model.pdf")
plt.show()

# --- MSE Plot ---
plt.figure(figsize=(8, 8))
plt.scatter(naive_mse_vector, mse_model_vector, alpha=0.7, edgecolor='k', s=50)
plt.xlabel("Naïve MSE per Cell", fontsize=14)
plt.ylabel("Model MSE per Cell", fontsize=14)
plt.title("Per-cell MSE: Naïve vs Model", fontsize=16)

# Identity line for reference
min_val = min(naive_mse_vector.min(), mse_model_vector.min())
max_val = max(naive_mse_vector.max(), mse_model_vector.max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='y = x')
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.xscale('log')
plt.yscale('log')

# Save the MSE plot image
# plt.savefig("/data/dagyeman/cellranger/bam_file_analysis/figures_ub/mae_mse_plots/1k_per_cell_mse_naive_vs_model.pdf")
plt.savefig("/data/dagyeman/cellranger/bam_file_analysis/figures_ur/mae_mse_plots/1k_per_cell_mse_naive_vs_model.pdf")
plt.show()
